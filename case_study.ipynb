# %% [markdown]
# ## Extract part

# %%
# extracting all the licences from the given API
url = 'https://api.crossref.org/works?sort=published&order=desc&rows=200' 
base_url = 'https://api.crossref.org/works'
params = {"sort": "published", "order": "desc", "rows": 200}

# %%
response = requests.get(base_url, params=params)
response.raise_for_status()
json_data = response.json()

# %%
# 2. Drill into the items list
items = json_data["message"]["items"] # pitatiyasto bashook na ["message"]["items"]
items
# Out:
# [{'indexed': {'date-parts': [[2022, 3, 29]],
#    'date-time': '2022-03-29T07:17:11Z',
#    'timestamp': 1648538231791},
#   'reference-count': 0,
#   'publisher': 'Elsevier BV',
#   'issue': '7',
#   'license': [{'start': {'date-parts': [[2203, 10, 1]],
#      'date-time': '2203-10-01T00:00:00Z',
#      'timestamp': 7376313600000},
#     'content-version': 'tdm',
#     'delay-in-days': 0,
#     'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['Aten Primaria'],
#   'published-print': {'date-parts': [[2203, 10]]},
#   'DOI': '10.1157/13053457',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2003, 11, 17]],
#    'date-time': '2003-11-17T16:44:58Z',
#    'timestamp': 1069087498000},
#   'page': '437-437',
#   'source': 'Crossref',
#   'is-referenced-by-count': 1,
#   'title': ['Prevalencia del uso preconcepcional del ácido fólico en el área norte de Pontevedra'],
#   'prefix': '10.1016',
#   'volume': '32',
#   'author': [{'given': 'A',
#     'family': 'Pérez-Vázquez',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'R',
#     'family': 'Vidal Álvarez',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'M',
#     'family': 'Castro Pazos',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'A',
#     'family': 'Aulet Ruiz',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '78',
#   'container-title': ['Atención Primaria'],
#   'link': [{'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/xml',
#     'content-type': 'text/xml',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'},
#    {'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/plain',
#     'content-type': 'text/plain',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'}],
#   'deposited': {'date-parts': [[2019, 2, 17]],
#    'date-time': '2019-02-17T01:23:25Z',
#    'timestamp': 1550366605000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://db.doyma.es/cgi-bin/wdbcgi.exe/doyma/mrevista.fulltext?pident=13053457'}},
#   'issued': {'date-parts': [[2203, 10]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '7'},
#   'alternative-id': ['13002413'],
#   'URL': 'https://doi.org/10.1157/13053457',
#   'ISSN': ['0212-6567', '1578-1275'],
#   'issn-type': [{'value': '0212-6567', 'type': 'print'},
#    {'value': '1578-1275', 'type': 'electronic'}],
#   'published': {'date-parts': [[2203, 10]]}},
#  {'indexed': {'date-parts': [[2022, 4, 1]],
#    'date-time': '2022-04-01T11:13:10Z',
#    'timestamp': 1648811590450},
#   'reference-count': 0,
#   'publisher': 'Elsevier BV',
#   'issue': '7',
#   'license': [{'start': {'date-parts': [[2203, 10, 1]],
#      'date-time': '2203-10-01T00:00:00Z',
#      'timestamp': 7376313600000},
#     'content-version': 'tdm',
#     'delay-in-days': 0,
#     'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['Aten Primaria'],
#   'published-print': {'date-parts': [[2203, 10]]},
#   'DOI': '10.1157/13053459',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2003, 11, 17]],
#    'date-time': '2003-11-17T16:44:58Z',
#    'timestamp': 1069087498000},
#   'page': '435b-435',
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Mastopatía tras tratamiento con estradiol y pantoprazol'],
#   'prefix': '10.1016',
#   'volume': '32',
#   'author': [{'given': 'A',
#     'family': 'Piedra Cerezal',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'L',
#     'family': 'Sánchez Álvarez',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'G',
#     'family': 'Manso Rodríguez',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'A',
#     'family': 'Hidalgo Balsera',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '78',
#   'container-title': ['Atención Primaria'],
#   'link': [{'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/xml',
#     'content-type': 'text/xml',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'},
#    {'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/plain',
#     'content-type': 'text/plain',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'}],
#   'deposited': {'date-parts': [[2019, 2, 17]],
#    'date-time': '2019-02-17T01:23:25Z',
#    'timestamp': 1550366605000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://db.doyma.es/cgi-bin/wdbcgi.exe/doyma/mrevista.fulltext?pident=13053459'}},
#   'issued': {'date-parts': [[2203, 10]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '7'},
#   'alternative-id': ['13002413'],
#   'URL': 'https://doi.org/10.1157/13053459',
#   'ISSN': ['0212-6567', '1578-1275'],
#   'issn-type': [{'value': '0212-6567', 'type': 'print'},
#    {'value': '1578-1275', 'type': 'electronic'}],
#   'published': {'date-parts': [[2203, 10]]}},
#  {'indexed': {'date-parts': [[2022, 4, 2]],
#    'date-time': '2022-04-02T08:47:24Z',
#    'timestamp': 1648889244489},
#   'reference-count': 0,
#   'publisher': 'Elsevier BV',
#   'issue': '7',
#   'license': [{'start': {'date-parts': [[2203, 10, 1]],
#      'date-time': '2203-10-01T00:00:00Z',
#      'timestamp': 7376313600000},
#     'content-version': 'tdm',
#     'delay-in-days': 0,
#     'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['Aten Primaria'],
#   'published-print': {'date-parts': [[2203, 10]]},
#   'DOI': '10.1157/13053456',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2003, 11, 17]],
#    'date-time': '2003-11-17T16:44:58Z',
#    'timestamp': 1069087498000},
#   'page': '438b-438',
#   'source': 'Crossref',
#   'is-referenced-by-count': 1,
#   'title': ['Sonambulismo asociado con zolpidem'],
#   'prefix': '10.1016',
#   'volume': '32',
#   'author': [{'given': 'M',
#     'family': 'Yanes Baonza',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'JM',
#     'family': 'Ferrer García-Borrás',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'A',
#     'family': 'Cabrera Majada',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'R',
#     'family': 'Sánchez González',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '78',
#   'container-title': ['Atención Primaria'],
#   'link': [{'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/xml',
#     'content-type': 'text/xml',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'},
#    {'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/plain',
#     'content-type': 'text/plain',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'}],
#   'deposited': {'date-parts': [[2019, 2, 17]],
#    'date-time': '2019-02-17T01:23:25Z',
#    'timestamp': 1550366605000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://db.doyma.es/cgi-bin/wdbcgi.exe/doyma/mrevista.fulltext?pident=13053456'}},
#   'issued': {'date-parts': [[2203, 10]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '7'},
#   'alternative-id': ['13002413'],
#   'URL': 'https://doi.org/10.1157/13053456',
#   'ISSN': ['0212-6567', '1578-1275'],
#   'issn-type': [{'value': '0212-6567', 'type': 'print'},
#    {'value': '1578-1275', 'type': 'electronic'}],
#   'published': {'date-parts': [[2203, 10]]}},
#  {'indexed': {'date-parts': [[2022, 4, 5]],
#    'date-time': '2022-04-05T10:39:27Z',
#    'timestamp': 1649155167162},
#   'reference-count': 0,
#   'publisher': 'Elsevier BV',
#   'issue': '7',
#   'license': [{'start': {'date-parts': [[2203, 10, 1]],
#      'date-time': '2203-10-01T00:00:00Z',
#      'timestamp': 7376313600000},
#     'content-version': 'tdm',
#     'delay-in-days': 0,
#     'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['Aten Primaria'],
#   'published-print': {'date-parts': [[2203, 10]]},
#   'DOI': '10.1157/13053452',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2003, 11, 17]],
#    'date-time': '2003-11-17T11:44:58Z',
#    'timestamp': 1069069498000},
#   'page': '440-440',
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Respuesta de la autora'],
#   'prefix': '10.1016',
#   'volume': '32',
#   'author': [{'given': 'I',
#     'family': 'Fernández Fernández',
#     'sequence': 'first',
#     'affiliation': []}],
#   'member': '78',
#   'container-title': ['Atención Primaria'],
#   'link': [{'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/xml',
#     'content-type': 'text/xml',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'},
#    {'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/plain',
#     'content-type': 'text/plain',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'}],
#   'deposited': {'date-parts': [[2019, 2, 16]],
#    'date-time': '2019-02-16T20:23:25Z',
#    'timestamp': 1550348605000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://db.doyma.es/cgi-bin/wdbcgi.exe/doyma/mrevista.fulltext?pident=13053452'}},
#   'issued': {'date-parts': [[2203, 10]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '7'},
#   'alternative-id': ['13002413'],
#   'URL': 'https://doi.org/10.1157/13053452',
#   'ISSN': ['0212-6567', '1578-1275'],
#   'issn-type': [{'value': '0212-6567', 'type': 'print'},
#    {'value': '1578-1275', 'type': 'electronic'}],
#   'published': {'date-parts': [[2203, 10]]}},
#  {'indexed': {'date-parts': [[2022, 3, 31]],
#    'date-time': '2022-03-31T07:19:57Z',
#    'timestamp': 1648711197444},
#   'reference-count': 0,
#   'publisher': 'Elsevier BV',
#   'issue': '7',
#   'license': [{'start': {'date-parts': [[2203, 10, 1]],
#      'date-time': '2203-10-01T00:00:00Z',
#      'timestamp': 7376313600000},
#     'content-version': 'tdm',
#     'delay-in-days': 0,
#     'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['Aten Primaria'],
#   'published-print': {'date-parts': [[2203, 10]]},
#   'DOI': '10.1157/13053449',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2003, 11, 17]],
#    'date-time': '2003-11-17T16:44:58Z',
#    'timestamp': 1069087498000},
#   'page': '441-441',
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Hepatitis C: diagnóstico y prevención desde la consulta de atención primaria'],
#   'prefix': '10.1016',
#   'volume': '32',
#   'author': [{'given': 'JI',
#     'family': 'Alastrué Loscos',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'M',
#     'family': 'Giner Valero',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'FJ',
#     'family': 'Beltrán Armada',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '78',
#   'container-title': ['Atención Primaria'],
#   'link': [{'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/xml',
#     'content-type': 'text/xml',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'},
#    {'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/plain',
#     'content-type': 'text/plain',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'}],
#   'deposited': {'date-parts': [[2019, 2, 17]],
#    'date-time': '2019-02-17T01:23:25Z',
#    'timestamp': 1550366605000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://db.doyma.es/cgi-bin/wdbcgi.exe/doyma/mrevista.fulltext?pident=13053449'}},
#   'issued': {'date-parts': [[2203, 10]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '7'},
#   'alternative-id': ['13002413'],
#   'URL': 'https://doi.org/10.1157/13053449',
#   'ISSN': ['0212-6567', '1578-1275'],
#   'issn-type': [{'value': '0212-6567', 'type': 'print'},
#    {'value': '1578-1275', 'type': 'electronic'}],
#   'published': {'date-parts': [[2203, 10]]}},
#  {'indexed': {'date-parts': [[2022, 4, 3]],
#    'date-time': '2022-04-03T20:51:47Z',
#    'timestamp': 1649019107577},
#   'reference-count': 0,
#   'publisher': 'Elsevier BV',
#   'issue': '7',
#   'license': [{'start': {'date-parts': [[2203, 10, 1]],
#      'date-time': '2203-10-01T00:00:00Z',
#      'timestamp': 7376313600000},
#     'content-version': 'tdm',
#     'delay-in-days': 0,
#     'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['Aten Primaria'],
#   'published-print': {'date-parts': [[2203, 10]]},
#   'DOI': '10.1157/13053460',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2003, 11, 17]],
#    'date-time': '2003-11-17T11:44:58Z',
#    'timestamp': 1069069498000},
#   'page': '434-434',
#   'source': 'Crossref',
#   'is-referenced-by-count': 1,
#   'title': ['Intoxicación por paracetamol líquidoen menores de 6 años: cambios en la dosis tóxica'],
#   'prefix': '10.1016',
#   'volume': '32',
#   'author': [{'given': 'E',
#     'family': 'Garcés Redolat',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'A',
#     'family': 'Parra Hernández',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'P',
#     'family': 'Munné Mas',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'G',
#     'family': 'Burillo-Putze',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '78',
#   'container-title': ['Atención Primaria'],
#   'link': [{'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/xml',
#     'content-type': 'text/xml',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'},
#    {'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/plain',
#     'content-type': 'text/plain',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'}],
#   'deposited': {'date-parts': [[2019, 2, 16]],
#    'date-time': '2019-02-16T20:23:25Z',
#    'timestamp': 1550348605000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://db.doyma.es/cgi-bin/wdbcgi.exe/doyma/mrevista.fulltext?pident=13053460'}},
#   'issued': {'date-parts': [[2203, 10]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '7'},
#   'alternative-id': ['13002413'],
#   'URL': 'https://doi.org/10.1157/13053460',
#   'ISSN': ['0212-6567', '1578-1275'],
#   'issn-type': [{'value': '0212-6567', 'type': 'print'},
#    {'value': '1578-1275', 'type': 'electronic'}],
#   'published': {'date-parts': [[2203, 10]]}},
#  {'indexed': {'date-parts': [[2022, 3, 30]],
#    'date-time': '2022-03-30T21:56:26Z',
#    'timestamp': 1648677386051},
#   'reference-count': 0,
#   'publisher': 'Elsevier BV',
#   'issue': '7',
#   'license': [{'start': {'date-parts': [[2203, 10, 1]],
#      'date-time': '2203-10-01T00:00:00Z',
#      'timestamp': 7376313600000},
#     'content-version': 'tdm',
#     'delay-in-days': 0,
#     'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['Aten Primaria'],
#   'published-print': {'date-parts': [[2203, 10]]},
#   'DOI': '10.1157/13053448',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2003, 11, 17]],
#    'date-time': '2003-11-17T16:44:58Z',
#    'timestamp': 1069087498000},
#   'page': '442-443',
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Respuesta de los autores'],
#   'prefix': '10.1016',
#   'volume': '32',
#   'author': [{'given': 'M.A',
#     'family': 'Martínez Adell',
#     'sequence': 'first',
#     'affiliation': []}],
#   'member': '78',
#   'container-title': ['Atención Primaria'],
#   'link': [{'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/xml',
#     'content-type': 'text/xml',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'},
#    {'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/plain',
#     'content-type': 'text/plain',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'}],
#   'deposited': {'date-parts': [[2019, 2, 17]],
#    'date-time': '2019-02-17T01:23:25Z',
#    'timestamp': 1550366605000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://db.doyma.es/cgi-bin/wdbcgi.exe/doyma/mrevista.fulltext?pident=13053448'}},
#   'issued': {'date-parts': [[2203, 10]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '7'},
#   'alternative-id': ['13002413'],
#   'URL': 'https://doi.org/10.1157/13053448',
#   'ISSN': ['0212-6567', '1578-1275'],
#   'issn-type': [{'value': '0212-6567', 'type': 'print'},
#    {'value': '1578-1275', 'type': 'electronic'}],
#   'published': {'date-parts': [[2203, 10]]}},
#  {'indexed': {'date-parts': [[2022, 4, 4]],
#    'date-time': '2022-04-04T05:42:24Z',
#    'timestamp': 1649050944707},
#   'reference-count': 0,
#   'publisher': 'Elsevier BV',
#   'issue': '7',
#   'license': [{'start': {'date-parts': [[2203, 10, 1]],
#      'date-time': '2203-10-01T00:00:00Z',
#      'timestamp': 7376313600000},
#     'content-version': 'tdm',
#     'delay-in-days': 0,
#     'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['Aten Primaria'],
#   'published-print': {'date-parts': [[2203, 10]]},
#   'DOI': '10.1157/13053451',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2003, 11, 17]],
#    'date-time': '2003-11-17T11:44:58Z',
#    'timestamp': 1069069498000},
#   'page': '441b-441',
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Prevalencia de hepatitis A y hepatopatías crónicas: un reto a desarrollar'],
#   'prefix': '10.1016',
#   'volume': '32',
#   'author': [{'given': 'P',
#     'family': 'Bachiller Luque',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'C',
#     'family': 'Navarro Cañadas',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'A',
#     'family': 'Almaraz Gómez',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'A',
#     'family': 'Orduña Domingo',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '78',
#   'container-title': ['Atención Primaria'],
#   'link': [{'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/xml',
#     'content-type': 'text/xml',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'},
#    {'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/plain',
#     'content-type': 'text/plain',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'}],
#   'deposited': {'date-parts': [[2019, 2, 16]],
#    'date-time': '2019-02-16T20:23:25Z',
#    'timestamp': 1550348605000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://db.doyma.es/cgi-bin/wdbcgi.exe/doyma/mrevista.fulltext?pident=13053451'}},
#   'issued': {'date-parts': [[2203, 10]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '7'},
#   'alternative-id': ['13002413'],
#   'URL': 'https://doi.org/10.1157/13053451',
#   'ISSN': ['0212-6567', '1578-1275'],
#   'issn-type': [{'value': '0212-6567', 'type': 'print'},
#    {'value': '1578-1275', 'type': 'electronic'}],
#   'published': {'date-parts': [[2203, 10]]}},
#  {'indexed': {'date-parts': [[2022, 4, 5]],
#    'date-time': '2022-04-05T07:18:43Z',
#    'timestamp': 1649143123538},
#   'reference-count': 0,
#   'publisher': 'Elsevier BV',
#   'issue': '7',
#   'license': [{'start': {'date-parts': [[2203, 10, 1]],
#      'date-time': '2203-10-01T00:00:00Z',
#      'timestamp': 7376313600000},
#     'content-version': 'tdm',
#     'delay-in-days': 0,
#     'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['Aten Primaria'],
#   'published-print': {'date-parts': [[2203, 10]]},
#   'DOI': '10.1157/13053458',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2003, 11, 17]],
#    'date-time': '2003-11-17T11:44:58Z',
#    'timestamp': 1069069498000},
#   'page': '435-436',
#   'source': 'Crossref',
#   'is-referenced-by-count': 5,
#   'title': ['La espirometría en el diagnóstico de la enfermedad pulmonar obstructiva crónica en atención primaria'],
#   'prefix': '10.1016',
#   'volume': '32',
#   'author': [{'given': 'JM',
#     'family': 'Manresa Presasa',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'J',
#     'family': 'Rebull Fatsinib',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'M',
#     'family': 'Miravalls Figuerolac',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'R',
#     'family': 'Caballol Angelatsd',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'P',
#     'family': 'Minué Magañae',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'R',
#     'family': 'Juan Franquetf',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '78',
#   'container-title': ['Atención Primaria'],
#   'link': [{'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/xml',
#     'content-type': 'text/xml',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'},
#    {'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/plain',
#     'content-type': 'text/plain',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'}],
#   'deposited': {'date-parts': [[2019, 2, 16]],
#    'date-time': '2019-02-16T20:23:25Z',
#    'timestamp': 1550348605000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://db.doyma.es/cgi-bin/wdbcgi.exe/doyma/mrevista.fulltext?pident=13053458'}},
#   'issued': {'date-parts': [[2203, 10]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '7'},
#   'alternative-id': ['13002413'],
#   'URL': 'https://doi.org/10.1157/13053458',
#   'ISSN': ['0212-6567', '1578-1275'],
#   'issn-type': [{'value': '0212-6567', 'type': 'print'},
#    {'value': '1578-1275', 'type': 'electronic'}],
#   'published': {'date-parts': [[2203, 10]]}},
#  {'indexed': {'date-parts': [[2024, 9, 16]],
#    'date-time': '2024-09-16T08:36:35Z',
#    'timestamp': 1726475795023},
#   'reference-count': 0,
#   'publisher': 'Elsevier BV',
#   'issue': '7',
#   'license': [{'start': {'date-parts': [[2203, 10, 1]],
#      'date-time': '2203-10-01T00:00:00Z',
#      'timestamp': 7376313600000},
#     'content-version': 'tdm',
#     'delay-in-days': 0,
#     'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['Aten Primaria'],
#   'published-print': {'date-parts': [[2203, 10]]},
#   'DOI': '10.1157/13053723',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2003, 11, 17]],
#    'date-time': '2003-11-17T11:44:58Z',
#    'timestamp': 1069069498000},
#   'page': '423-424',
#   'source': 'Crossref',
#   'is-referenced-by-count': 19,
#   'title': ['Análisis de la demanda en los servicios de urgencias de Barcelona'],
#   'prefix': '10.1016',
#   'volume': '32',
#   'author': [{'given': 'E',
#     'family': 'Torné Vilagrasa',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'A',
#     'family': 'Guarga Rojas',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'MG',
#     'family': 'Torras Boatella',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'A',
#     'family': 'Pozuelo García',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'M',
#     'family': 'Pasarin Rua',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'C',
#     'family': 'Borrell Thió',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '78',
#   'container-title': ['Atención Primaria'],
#   'link': [{'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/xml',
#     'content-type': 'text/xml',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'},
#    {'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/plain',
#     'content-type': 'text/plain',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'}],
#   'deposited': {'date-parts': [[2019, 2, 16]],
#    'date-time': '2019-02-16T20:23:25Z',
#    'timestamp': 1550348605000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://db.doyma.es/cgi-bin/wdbcgi.exe/doyma/mrevista.fulltext?pident=13053723'}},
#   'issued': {'date-parts': [[2203, 10]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '7'},
#   'alternative-id': ['13002413'],
#   'URL': 'https://doi.org/10.1157/13053723',
#   'ISSN': ['0212-6567', '1578-1275'],
#   'issn-type': [{'value': '0212-6567', 'type': 'print'},
#    {'value': '1578-1275', 'type': 'electronic'}],
#   'published': {'date-parts': [[2203, 10]]}},
#  {'indexed': {'date-parts': [[2022, 4, 2]],
#    'date-time': '2022-04-02T11:41:51Z',
#    'timestamp': 1648899711308},
#   'reference-count': 0,
#   'publisher': 'Elsevier BV',
#   'issue': '7',
#   'license': [{'start': {'date-parts': [[2203, 10, 1]],
#      'date-time': '2203-10-01T00:00:00Z',
#      'timestamp': 7376313600000},
#     'content-version': 'tdm',
#     'delay-in-days': 0,
#     'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['Aten Primaria'],
#   'published-print': {'date-parts': [[2203, 10]]},
#   'DOI': '10.1157/13053468',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2003, 11, 17]],
#    'date-time': '2003-11-17T16:44:58Z',
#    'timestamp': 1069087498000},
#   'page': '401-402',
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Una apuesta por la calidad, la seriedad y la independencia científica'],
#   'prefix': '10.1016',
#   'volume': '32',
#   'author': [{'given': 'M',
#     'family': 'Ferran Mercadé',
#     'sequence': 'first',
#     'affiliation': []}],
#   'member': '78',
#   'container-title': ['Atención Primaria'],
#   'link': [{'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/xml',
#     'content-type': 'text/xml',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'},
#    {'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/plain',
#     'content-type': 'text/plain',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'}],
#   'deposited': {'date-parts': [[2019, 2, 17]],
#    'date-time': '2019-02-17T01:23:25Z',
#    'timestamp': 1550366605000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://db.doyma.es/cgi-bin/wdbcgi.exe/doyma/mrevista.fulltext?pident=13053468'}},
#   'issued': {'date-parts': [[2203, 10]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '7'},
#   'alternative-id': ['13002413'],
#   'URL': 'https://doi.org/10.1157/13053468',
#   'ISSN': ['0212-6567', '1578-1275'],
#   'issn-type': [{'value': '0212-6567', 'type': 'print'},
#    {'value': '1578-1275', 'type': 'electronic'}],
#   'published': {'date-parts': [[2203, 10]]}},
#  {'indexed': {'date-parts': [[2025, 5, 30]],
#    'date-time': '2025-05-30T05:22:24Z',
#    'timestamp': 1748582544347},
#   'reference-count': 0,
#   'publisher': 'Elsevier BV',
#   'issue': '7',
#   'license': [{'start': {'date-parts': [[2203, 10, 1]],
#      'date-time': '2203-10-01T00:00:00Z',
#      'timestamp': 7376313600000},
#     'content-version': 'tdm',
#     'delay-in-days': 0,
#     'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['Aten Primaria'],
#   'published-print': {'date-parts': [[2203, 10]]},
#   'DOI': '10.1157/13053466',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2003, 11, 17]],
#    'date-time': '2003-11-17T16:44:58Z',
#    'timestamp': 1069087498000},
#   'page': '408-409',
#   'source': 'Crossref',
#   'is-referenced-by-count': 1,
#   'title': ['Comentario: Prevención de los factores de riesgo de los trastornos de la conducta alimentaria en adolescentes:'],
#   'prefix': '10.1016',
#   'volume': '32',
#   'author': [{'given': 'P.J',
#     'family': 'Ruiz Lázaro',
#     'sequence': 'first',
#     'affiliation': []}],
#   'member': '78',
#   'container-title': ['Atención Primaria'],
#   'link': [{'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/xml',
#     'content-type': 'text/xml',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'},
#    {'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/plain',
#     'content-type': 'text/plain',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'}],
#   'deposited': {'date-parts': [[2019, 2, 17]],
#    'date-time': '2019-02-17T01:23:25Z',
#    'timestamp': 1550366605000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://db.doyma.es/cgi-bin/wdbcgi.exe/doyma/mrevista.fulltext?pident=13053466'}},
#   'issued': {'date-parts': [[2203, 10]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '7'},
#   'alternative-id': ['13002413'],
#   'URL': 'https://doi.org/10.1157/13053466',
#   'ISSN': ['0212-6567', '1578-1275'],
#   'issn-type': [{'value': '0212-6567', 'type': 'print'},
#    {'value': '1578-1275', 'type': 'electronic'}],
#   'published': {'date-parts': [[2203, 10]]}},
#  {'indexed': {'date-parts': [[2022, 3, 29]],
#    'date-time': '2022-03-29T22:52:50Z',
#    'timestamp': 1648594370459},
#   'reference-count': 0,
#   'publisher': 'Elsevier BV',
#   'issue': '7',
#   'license': [{'start': {'date-parts': [[2203, 10, 1]],
#      'date-time': '2203-10-01T00:00:00Z',
#      'timestamp': 7376313600000},
#     'content-version': 'tdm',
#     'delay-in-days': 0,
#     'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['Aten Primaria'],
#   'published-print': {'date-parts': [[2203, 10]]},
#   'DOI': '10.1157/13053453',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2003, 11, 17]],
#    'date-time': '2003-11-17T11:44:58Z',
#    'timestamp': 1069069498000},
#   'page': '439-439',
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Profundizando en los porqués y los cómos de la investigación en atención primaria'],
#   'prefix': '10.1016',
#   'volume': '32',
#   'author': [{'given': 'MA',
#     'family': 'Prieto Rodríguez',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'JC',
#     'family': 'March Cerdá',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '78',
#   'container-title': ['Atención Primaria'],
#   'link': [{'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/xml',
#     'content-type': 'text/xml',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'},
#    {'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/plain',
#     'content-type': 'text/plain',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'}],
#   'deposited': {'date-parts': [[2019, 2, 16]],
#    'date-time': '2019-02-16T20:23:25Z',
#    'timestamp': 1550348605000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://db.doyma.es/cgi-bin/wdbcgi.exe/doyma/mrevista.fulltext?pident=13053453'}},
#   'issued': {'date-parts': [[2203, 10]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '7'},
#   'alternative-id': ['13002413'],
#   'URL': 'https://doi.org/10.1157/13053453',
#   'ISSN': ['0212-6567', '1578-1275'],
#   'issn-type': [{'value': '0212-6567', 'type': 'print'},
#    {'value': '1578-1275', 'type': 'electronic'}],
#   'published': {'date-parts': [[2203, 10]]}},
#  {'indexed': {'date-parts': [[2022, 3, 28]],
#    'date-time': '2022-03-28T21:30:50Z',
#    'timestamp': 1648503050273},
#   'reference-count': 0,
#   'publisher': 'Elsevier BV',
#   'issue': '7',
#   'license': [{'start': {'date-parts': [[2203, 10, 1]],
#      'date-time': '2203-10-01T00:00:00Z',
#      'timestamp': 7376313600000},
#     'content-version': 'tdm',
#     'delay-in-days': 0,
#     'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['Aten Primaria'],
#   'published-print': {'date-parts': [[2203, 10]]},
#   'DOI': '10.1157/13053455',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2003, 11, 17]],
#    'date-time': '2003-11-17T16:44:58Z',
#    'timestamp': 1069087498000},
#   'page': '438-438',
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Síndrome de latigazo cervical y pruebas radiológicas'],
#   'prefix': '10.1016',
#   'volume': '32',
#   'author': [{'given': 'G',
#     'family': 'Burillo-Putze',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'JM',
#     'family': 'Osuna Peña',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'V',
#     'family': 'García Marín',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'N',
#     'family': 'García Marín',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '78',
#   'container-title': ['Atención Primaria'],
#   'link': [{'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/xml',
#     'content-type': 'text/xml',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'},
#    {'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/plain',
#     'content-type': 'text/plain',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'}],
#   'deposited': {'date-parts': [[2019, 2, 17]],
#    'date-time': '2019-02-17T01:23:25Z',
#    'timestamp': 1550366605000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://db.doyma.es/cgi-bin/wdbcgi.exe/doyma/mrevista.fulltext?pident=13053455'}},
#   'issued': {'date-parts': [[2203, 10]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '7'},
#   'alternative-id': ['13002413'],
#   'URL': 'https://doi.org/10.1157/13053455',
#   'ISSN': ['0212-6567', '1578-1275'],
#   'issn-type': [{'value': '0212-6567', 'type': 'print'},
#    {'value': '1578-1275', 'type': 'electronic'}],
#   'published': {'date-parts': [[2203, 10]]}},
#  {'indexed': {'date-parts': [[2022, 4, 2]],
#    'date-time': '2022-04-02T04:30:17Z',
#    'timestamp': 1648873817605},
#   'reference-count': 0,
#   'publisher': 'Elsevier BV',
#   'issue': '7',
#   'license': [{'start': {'date-parts': [[2203, 10, 1]],
#      'date-time': '2203-10-01T00:00:00Z',
#      'timestamp': 7376313600000},
#     'content-version': 'tdm',
#     'delay-in-days': 0,
#     'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['Aten Primaria'],
#   'published-print': {'date-parts': [[2203, 10]]},
#   'DOI': '10.1157/13053467',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2003, 11, 17]],
#    'date-time': '2003-11-17T16:44:58Z',
#    'timestamp': 1069087498000},
#   'page': '403-407',
#   'source': 'Crossref',
#   'is-referenced-by-count': 1,
#   'title': ['Factores de riesgo relacionados con trastornos en la conducta alimentaria en una comunidad de escolares'],
#   'prefix': '10.1016',
#   'volume': '32',
#   'author': [{'given': 'M',
#     'family': 'Díaz Benavente',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'F',
#     'family': 'Rodríguez Morilla',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'C',
#     'family': 'Martín Leal',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'MV',
#     'family': 'Hiruela Benjumea',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '78',
#   'container-title': ['Atención Primaria'],
#   'link': [{'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/xml',
#     'content-type': 'text/xml',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'},
#    {'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/plain',
#     'content-type': 'text/plain',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'}],
#   'deposited': {'date-parts': [[2019, 2, 17]],
#    'date-time': '2019-02-17T01:23:25Z',
#    'timestamp': 1550366605000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://db.doyma.es/cgi-bin/wdbcgi.exe/doyma/mrevista.fulltext?pident=13053467'}},
#   'issued': {'date-parts': [[2203, 10]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '7'},
#   'alternative-id': ['13002413'],
#   'URL': 'https://doi.org/10.1157/13053467',
#   'ISSN': ['0212-6567', '1578-1275'],
#   'issn-type': [{'value': '0212-6567', 'type': 'print'},
#    {'value': '1578-1275', 'type': 'electronic'}],
#   'published': {'date-parts': [[2203, 10]]}},
#  {'indexed': {'date-parts': [[2022, 4, 1]],
#    'date-time': '2022-04-01T03:47:35Z',
#    'timestamp': 1648784855935},
#   'reference-count': 0,
#   'publisher': 'Elsevier BV',
#   'issue': '7',
#   'license': [{'start': {'date-parts': [[2203, 10, 1]],
#      'date-time': '2203-10-01T00:00:00Z',
#      'timestamp': 7376313600000},
#     'content-version': 'tdm',
#     'delay-in-days': 0,
#     'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['Aten Primaria'],
#   'published-print': {'date-parts': [[2203, 10]]},
#   'DOI': '10.1157/13053454',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2003, 11, 17]],
#    'date-time': '2003-11-17T16:44:58Z',
#    'timestamp': 1069087498000},
#   'page': '439b-439',
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Respuesta de los autores'],
#   'prefix': '10.1016',
#   'volume': '32',
#   'author': [{'given': 'S',
#     'family': 'Castiella',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'MA',
#     'family': 'López Vázquez',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '78',
#   'container-title': ['Atención Primaria'],
#   'link': [{'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/xml',
#     'content-type': 'text/xml',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'},
#    {'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/plain',
#     'content-type': 'text/plain',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'}],
#   'deposited': {'date-parts': [[2019, 2, 17]],
#    'date-time': '2019-02-17T01:23:25Z',
#    'timestamp': 1550366605000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://db.doyma.es/cgi-bin/wdbcgi.exe/doyma/mrevista.fulltext?pident=13053454'}},
#   'issued': {'date-parts': [[2203, 10]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '7'},
#   'alternative-id': ['13002413'],
#   'URL': 'https://doi.org/10.1157/13053454',
#   'ISSN': ['0212-6567', '1578-1275'],
#   'issn-type': [{'value': '0212-6567', 'type': 'print'},
#    {'value': '1578-1275', 'type': 'electronic'}],
#   'published': {'date-parts': [[2203, 10]]}},
#  {'indexed': {'date-parts': [[2022, 4, 5]],
#    'date-time': '2022-04-05T06:07:38Z',
#    'timestamp': 1649138858401},
#   'reference-count': 0,
#   'publisher': 'Elsevier BV',
#   'issue': '7',
#   'license': [{'start': {'date-parts': [[2203, 10, 1]],
#      'date-time': '2203-10-01T00:00:00Z',
#      'timestamp': 7376313600000},
#     'content-version': 'tdm',
#     'delay-in-days': 0,
#     'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['Aten Primaria'],
#   'published-print': {'date-parts': [[2203, 10]]},
#   'DOI': '10.1157/13053463',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2003, 11, 17]],
#    'date-time': '2003-11-17T11:44:58Z',
#    'timestamp': 1069069498000},
#   'page': '420-422',
#   'source': 'Crossref',
#   'is-referenced-by-count': 5,
#   'title': ['El riesgo coronario en España y el tratamiento con fármacos hipolipemiantes'],
#   'prefix': '10.1016',
#   'volume': '32',
#   'author': [{'given': 'A',
#     'family': 'Maiques Galán',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'F',
#     'family': 'Villar Álvarez',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'C',
#     'family': 'Llor Vila',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'J',
#     'family': 'Torcal Laguna',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '78',
#   'container-title': ['Atención Primaria'],
#   'link': [{'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/xml',
#     'content-type': 'text/xml',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'},
#    {'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/plain',
#     'content-type': 'text/plain',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'}],
#   'deposited': {'date-parts': [[2019, 2, 16]],
#    'date-time': '2019-02-16T20:23:25Z',
#    'timestamp': 1550348605000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://db.doyma.es/cgi-bin/wdbcgi.exe/doyma/mrevista.fulltext?pident=13053463'}},
#   'issued': {'date-parts': [[2203, 10]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '7'},
#   'alternative-id': ['13002413'],
#   'URL': 'https://doi.org/10.1157/13053463',
#   'ISSN': ['0212-6567', '1578-1275'],
#   'issn-type': [{'value': '0212-6567', 'type': 'print'},
#    {'value': '1578-1275', 'type': 'electronic'}],
#   'published': {'date-parts': [[2203, 10]]}},
#  {'indexed': {'date-parts': [[2022, 4, 4]],
#    'date-time': '2022-04-04T14:54:36Z',
#    'timestamp': 1649084076462},
#   'reference-count': 0,
#   'publisher': 'Elsevier BV',
#   'issue': '7',
#   'license': [{'start': {'date-parts': [[2203, 10, 1]],
#      'date-time': '2203-10-01T00:00:00Z',
#      'timestamp': 7376313600000},
#     'content-version': 'tdm',
#     'delay-in-days': 0,
#     'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['Aten Primaria'],
#   'published-print': {'date-parts': [[2203, 10]]},
#   'DOI': '10.1157/13053461',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2003, 11, 17]],
#    'date-time': '2003-11-17T16:44:58Z',
#    'timestamp': 1069087498000},
#   'page': '425-433',
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Violencia en la pareja: papel del médico de familia'],
#   'prefix': '10.1016',
#   'volume': '32',
#   'author': [{'given': 'MC',
#     'family': 'Fernández Alonso',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'S',
#     'family': 'Herrero Velázquez',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'F',
#     'family': 'Buitrago Ramírez',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'R',
#     'family': 'Ciurana Misol',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'L',
#     'family': 'Chocron Bentata',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'J',
#     'family': 'García Campayo',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'C',
#     'family': 'Montón Franco',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'MJ',
#     'family': 'Redondo Granado',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'MJ',
#     'family': 'Tizón García',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '78',
#   'container-title': ['Atención Primaria'],
#   'link': [{'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/xml',
#     'content-type': 'text/xml',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'},
#    {'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/plain',
#     'content-type': 'text/plain',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'}],
#   'deposited': {'date-parts': [[2019, 2, 17]],
#    'date-time': '2019-02-17T01:23:25Z',
#    'timestamp': 1550366605000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://db.doyma.es/cgi-bin/wdbcgi.exe/doyma/mrevista.fulltext?pident=13053461'}},
#   'issued': {'date-parts': [[2203, 10]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '7'},
#   'alternative-id': ['13002413'],
#   'URL': 'https://doi.org/10.1157/13053461',
#   'ISSN': ['0212-6567', '1578-1275'],
#   'issn-type': [{'value': '0212-6567', 'type': 'print'},
#    {'value': '1578-1275', 'type': 'electronic'}],
#   'published': {'date-parts': [[2203, 10]]}},
#  {'indexed': {'date-parts': [[2022, 4, 5]],
#    'date-time': '2022-04-05T10:12:58Z',
#    'timestamp': 1649153578073},
#   'reference-count': 0,
#   'publisher': 'Elsevier BV',
#   'issue': '7',
#   'license': [{'start': {'date-parts': [[2203, 10, 1]],
#      'date-time': '2203-10-01T00:00:00Z',
#      'timestamp': 7376313600000},
#     'content-version': 'tdm',
#     'delay-in-days': 0,
#     'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['Aten Primaria'],
#   'published-print': {'date-parts': [[2203, 10]]},
#   'DOI': '10.1157/13053465',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2003, 11, 17]],
#    'date-time': '2003-11-17T16:44:58Z',
#    'timestamp': 1069087498000},
#   'page': '410-414',
#   'source': 'Crossref',
#   'is-referenced-by-count': 6,
#   'title': ['Epidemiología e impacto de la incontinencia urinaria en mujeres de 40 a 65 años de edad en un área sanitaria de Madrid'],
#   'prefix': '10.1016',
#   'volume': '32',
#   'author': [{'given': 'E',
#     'family': 'Nieto Blanco',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'J',
#     'family': 'Camacho Pérez',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'V',
#     'family': 'Dávila Álvarez',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'MP',
#     'family': 'Ledo García',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'P',
#     'family': 'Moriano Bejar',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'M',
#     'family': 'Pérez Lorente',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'L',
#     'family': 'Serrano Molina',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'B',
#     'family': 'Fonseca Redondo',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '78',
#   'container-title': ['Atención Primaria'],
#   'link': [{'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/xml',
#     'content-type': 'text/xml',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'},
#    {'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/plain',
#     'content-type': 'text/plain',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'}],
#   'deposited': {'date-parts': [[2019, 2, 17]],
#    'date-time': '2019-02-17T01:23:25Z',
#    'timestamp': 1550366605000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://db.doyma.es/cgi-bin/wdbcgi.exe/doyma/mrevista.fulltext?pident=13053465'}},
#   'issued': {'date-parts': [[2203, 10]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '7'},
#   'alternative-id': ['13002413'],
#   'URL': 'https://doi.org/10.1157/13053465',
#   'ISSN': ['0212-6567', '1578-1275'],
#   'issn-type': [{'value': '0212-6567', 'type': 'print'},
#    {'value': '1578-1275', 'type': 'electronic'}],
#   'published': {'date-parts': [[2203, 10]]}},
#  {'indexed': {'date-parts': [[2022, 4, 2]],
#    'date-time': '2022-04-02T07:20:39Z',
#    'timestamp': 1648884039449},
#   'reference-count': 0,
#   'publisher': 'Elsevier BV',
#   'issue': '7',
#   'license': [{'start': {'date-parts': [[2203, 10, 1]],
#      'date-time': '2203-10-01T00:00:00Z',
#      'timestamp': 7376313600000},
#     'content-version': 'tdm',
#     'delay-in-days': 0,
#     'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['Aten Primaria'],
#   'published-print': {'date-parts': [[2203, 10]]},
#   'DOI': '10.1157/13053464',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2003, 11, 17]],
#    'date-time': '2003-11-17T16:44:58Z',
#    'timestamp': 1069087498000},
#   'page': '415-419',
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Estudio de la marca en la prescripción de genéricos en 6 centros de salud durante el año 2001'],
#   'prefix': '10.1016',
#   'volume': '32',
#   'author': [{'given': 'G',
#     'family': 'Carmona Ibáñez',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'J',
#     'family': 'Guevara Serrano',
# ...
#   'URL': 'https://doi.org/10.12927/cjnl.2016.24988',
#   'ISSN': ['1929-6355'],
#   'issn-type': [{'value': '1929-6355', 'type': 'electronic'}],
#   'published': {'date-parts': [[2106, 12, 6]]}},
#  {'indexed': {'date-parts': [[2022, 4, 3]],
#    'date-time': '2022-04-03T05:07:34Z',
#    'timestamp': 1648962454649},
#   'reference-count': 0,
#   'publisher': 'Longwoods Publishing',
#   'issue': '4',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['CJNL'],
#   'published-print': {'date-parts': [[2106, 12, 6]]},
#   'DOI': '10.12927/cjnl.2016.24990',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2017, 4, 25]],
#    'date-time': '2017-04-25T11:08:02Z',
#    'timestamp': 1493118482000},
#   'page': '1-4',
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Looking Back and Moving Forwards'],
#   'prefix': '10.12927',
#   'volume': '29',
#   'author': [{'given': 'Lynn',
#     'family': 'Nagle',
#     'sequence': 'first',
#     'affiliation': []}],
#   'member': '5072',
#   'container-title': ['Canadian Journal of Nursing Leadership'],
#   'deposited': {'date-parts': [[2017, 4, 25]],
#    'date-time': '2017-04-25T11:08:03Z',
#    'timestamp': 1493118483000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://www.longwoods.com/content/24990'}},
#   'issued': {'date-parts': [[2106, 12, 6]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '4',
#    'published-print': {'date-parts': [[2106, 12, 6]]}},
#   'URL': 'https://doi.org/10.12927/cjnl.2016.24990',
#   'ISSN': ['1929-6355'],
#   'issn-type': [{'value': '1929-6355', 'type': 'electronic'}],
#   'published': {'date-parts': [[2106, 12, 6]]}},
#  {'indexed': {'date-parts': [[2025, 5, 26]],
#    'date-time': '2025-05-26T12:44:26Z',
#    'timestamp': 1748263466393},
#   'reference-count': 0,
#   'publisher': 'Longwoods Publishing',
#   'issue': '4',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['CJNL'],
#   'published-print': {'date-parts': [[2106, 12, 6]]},
#   'DOI': '10.12927/cjnl.2016.24983',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2017, 4, 25]],
#    'date-time': '2017-04-25T07:08:02Z',
#    'timestamp': 1493104082000},
#   'page': '59-69',
#   'source': 'Crossref',
#   'is-referenced-by-count': 7,
#   'title': ['Organizational Commitment and Nurses Characteristics as Predictors of Job Involvement'],
#   'prefix': '10.12927',
#   'volume': '29',
#   'author': [{'given': 'Kamila',
#     'family': 'Alammar',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'Mashael',
#     'family': 'Alamrani',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'Sara',
#     'family': 'Alqahtani',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'Muayyad',
#     'family': 'Ahmad',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '5072',
#   'container-title': ['Canadian Journal of Nursing Leadership'],
#   'deposited': {'date-parts': [[2017, 4, 25]],
#    'date-time': '2017-04-25T07:08:10Z',
#    'timestamp': 1493104090000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://www.longwoods.com/content/24983'}},
#   'issued': {'date-parts': [[2106, 12, 6]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '4',
#    'published-print': {'date-parts': [[2106, 12, 6]]}},
#   'URL': 'https://doi.org/10.12927/cjnl.2016.24983',
#   'ISSN': ['1929-6355'],
#   'issn-type': [{'value': '1929-6355', 'type': 'electronic'}],
#   'published': {'date-parts': [[2106, 12, 6]]}},
#  {'indexed': {'date-parts': [[2022, 3, 30]],
#    'date-time': '2022-03-30T00:23:37Z',
#    'timestamp': 1648599817681},
#   'reference-count': 0,
#   'publisher': 'Longwoods Publishing',
#   'issue': '4',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['CJNL'],
#   'published-print': {'date-parts': [[2106, 12, 6]]},
#   'DOI': '10.12927/cjnl.2016.24987',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2017, 4, 25]],
#    'date-time': '2017-04-25T11:08:02Z',
#    'timestamp': 1493118482000},
#   'page': '13-18',
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Tribute to Dr. Heather K. Spence Laschinger'],
#   'prefix': '10.12927',
#   'volume': '29',
#   'author': [{'given': 'Carol',
#     'family': 'Wong',
#     'sequence': 'first',
#     'affiliation': []}],
#   'member': '5072',
#   'container-title': ['Canadian Journal of Nursing Leadership'],
#   'deposited': {'date-parts': [[2017, 4, 25]],
#    'date-time': '2017-04-25T11:08:06Z',
#    'timestamp': 1493118486000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://www.longwoods.com/content/24987'}},
#   'issued': {'date-parts': [[2106, 12, 6]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '4',
#    'published-print': {'date-parts': [[2106, 12, 6]]}},
#   'URL': 'https://doi.org/10.12927/cjnl.2016.24987',
#   'ISSN': ['1929-6355'],
#   'issn-type': [{'value': '1929-6355', 'type': 'electronic'}],
#   'published': {'date-parts': [[2106, 12, 6]]}},
#  {'indexed': {'date-parts': [[2024, 7, 2]],
#    'date-time': '2024-07-02T21:18:27Z',
#    'timestamp': 1719955107690},
#   'reference-count': 0,
#   'publisher': 'Longwoods Publishing',
#   'issue': '4',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['CJNL'],
#   'published-print': {'date-parts': [[2106, 12, 6]]},
#   'DOI': '10.12927/cjnl.2016.24985',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2017, 4, 25]],
#    'date-time': '2017-04-25T11:08:02Z',
#    'timestamp': 1493118482000},
#   'page': '35-45',
#   'source': 'Crossref',
#   'is-referenced-by-count': 5,
#   'title': ['Implementing a Just Culture: Perceptions of Nurse Managers of Required Knowledge, Skills and Attitudes'],
#   'prefix': '10.12927',
#   'volume': '29',
#   'author': [{'given': 'Michelle',
#     'family': 'Freeman',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'Linda',
#     'family': 'Morrow',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'Margo',
#     'family': 'Cameron',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'Karen',
#     'family': 'McCullough',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '5072',
#   'container-title': ['Canadian Journal of Nursing Leadership'],
#   'deposited': {'date-parts': [[2017, 4, 25]],
#    'date-time': '2017-04-25T11:08:08Z',
#    'timestamp': 1493118488000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://www.longwoods.com/content/24985'}},
#   'issued': {'date-parts': [[2106, 12, 6]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '4',
#    'published-print': {'date-parts': [[2106, 12, 6]]}},
#   'URL': 'https://doi.org/10.12927/cjnl.2016.24985',
#   'ISSN': ['1929-6355'],
#   'issn-type': [{'value': '1929-6355', 'type': 'electronic'}],
#   'published': {'date-parts': [[2106, 12, 6]]}},
#  {'indexed': {'date-parts': [[2022, 4, 3]],
#    'date-time': '2022-04-03T02:27:30Z',
#    'timestamp': 1648952850943},
#   'reference-count': 0,
#   'publisher': 'Longwoods Publishing',
#   'issue': '4',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['CJNL'],
#   'published-print': {'date-parts': [[2106, 12, 6]]},
#   'DOI': '10.12927/cjnl.2016.24982',
#   'type': 'journal-issue',
#   'created': {'date-parts': [[2017, 4, 25]],
#    'date-time': '2017-04-25T11:08:03Z',
#    'timestamp': 1493118483000},
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'prefix': '10.12927',
#   'volume': '29',
#   'member': '5072',
#   'container-title': ['Canadian Journal of Nursing Leadership'],
#   'deposited': {'date-parts': [[2017, 4, 25]],
#    'date-time': '2017-04-25T11:08:03Z',
#    'timestamp': 1493118483000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://www.longwoods.com/publications/nursingleadership/24982'}},
#   'issued': {'date-parts': [[2106, 12, 6]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '4',
#    'published-print': {'date-parts': [[2106, 12, 6]]}},
#   'URL': 'https://doi.org/10.12927/cjnl.2016.24982',
#   'ISSN': ['1929-6355'],
#   'issn-type': [{'value': '1929-6355', 'type': 'electronic'}],
#   'published': {'date-parts': [[2106, 12, 6]]}},
#  {'indexed': {'date-parts': [[2024, 9, 13]],
#    'date-time': '2024-09-13T00:17:01Z',
#    'timestamp': 1726186621941},
#   'reference-count': 0,
#   'publisher': 'Longwoods Publishing',
#   'issue': '4',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['CJNL'],
#   'published-print': {'date-parts': [[2106, 12, 6]]},
#   'DOI': '10.12927/cjnl.2016.24984',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2017, 4, 25]],
#    'date-time': '2017-04-25T07:08:02Z',
#    'timestamp': 1493104082000},
#   'page': '46-58',
#   'source': 'Crossref',
#   'is-referenced-by-count': 3,
#   'title': ['Optimizing Registered Nurse Roles in the Delivery of Cancer Survivorship Care within Primary Care Settings'],
#   'prefix': '10.12927',
#   'volume': '29',
#   'author': [{'given': 'Lindsay',
#     'family': 'Yuille',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'Denise',
#     'family': 'Bryant-Lukosius',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'Ruta',
#     'family': 'Valaitis',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'Lisa',
#     'family': 'Dolovich',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '5072',
#   'container-title': ['Canadian Journal of Nursing Leadership'],
#   'deposited': {'date-parts': [[2017, 4, 25]],
#    'date-time': '2017-04-25T07:08:09Z',
#    'timestamp': 1493104089000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://www.longwoods.com/content/24984'}},
#   'issued': {'date-parts': [[2106, 12, 6]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '4',
#    'published-print': {'date-parts': [[2106, 12, 6]]}},
#   'URL': 'https://doi.org/10.12927/cjnl.2016.24984',
#   'ISSN': ['1929-6355'],
#   'issn-type': [{'value': '1929-6355', 'type': 'electronic'}],
#   'published': {'date-parts': [[2106, 12, 6]]}},
#  {'indexed': {'date-parts': [[2022, 4, 1]],
#    'date-time': '2022-04-01T14:33:35Z',
#    'timestamp': 1648823615332},
#   'reference-count': 0,
#   'publisher': 'Longwoods Publishing',
#   'issue': '4',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['CJNL'],
#   'published-print': {'date-parts': [[2106, 12, 6]]},
#   'DOI': '10.12927/cjnl.2016.24986',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2017, 4, 25]],
#    'date-time': '2017-04-25T11:08:02Z',
#    'timestamp': 1493118482000},
#   'page': '19-34',
#   'source': 'Crossref',
#   'is-referenced-by-count': 2,
#   'title': ['Engaging Nursing Voice and Presence During the Federal Election Campaign 2015'],
#   'prefix': '10.12927',
#   'volume': '29',
#   'author': [{'given': 'Nora',
#     'family': 'Whyte',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'Susan',
#     'family': 'Duncan',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '5072',
#   'container-title': ['Canadian Journal of Nursing Leadership'],
#   'deposited': {'date-parts': [[2017, 4, 25]],
#    'date-time': '2017-04-25T11:08:07Z',
#    'timestamp': 1493118487000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://www.longwoods.com/content/24986'}},
#   'issued': {'date-parts': [[2106, 12, 6]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '4',
#    'published-print': {'date-parts': [[2106, 12, 6]]}},
#   'URL': 'https://doi.org/10.12927/cjnl.2016.24986',
#   'ISSN': ['1929-6355'],
#   'issn-type': [{'value': '1929-6355', 'type': 'electronic'}],
#   'published': {'date-parts': [[2106, 12, 6]]}},
#  {'indexed': {'date-parts': [[2025, 5, 27]],
#    'date-time': '2025-05-27T15:11:13Z',
#    'timestamp': 1748358673836},
#   'reference-count': 0,
#   'publisher': 'Longwoods Publishing',
#   'issue': '4',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['CJNL'],
#   'published-print': {'date-parts': [[2106, 12, 6]]},
#   'DOI': '10.12927/cjnl.2016.24989',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2017, 4, 25]],
#    'date-time': '2017-04-25T07:08:02Z',
#    'timestamp': 1493104082000},
#   'page': '8-9',
#   'source': 'Crossref',
#   'is-referenced-by-count': 5,
#   'title': ['When More Is Not Always Better: Choosing Nursing Interventions Wisely'],
#   'prefix': '10.12927',
#   'volume': '29',
#   'author': [{'given': 'Barb',
#     'family': 'Shellian',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'Wendy',
#     'family': 'Levinson',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '5072',
#   'container-title': ['Canadian Journal of Nursing Leadership'],
#   'deposited': {'date-parts': [[2017, 4, 25]],
#    'date-time': '2017-04-25T07:08:04Z',
#    'timestamp': 1493104084000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://www.longwoods.com/content/24989'}},
#   'issued': {'date-parts': [[2106, 12, 6]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '4',
#    'published-print': {'date-parts': [[2106, 12, 6]]}},
#   'URL': 'https://doi.org/10.12927/cjnl.2016.24989',
#   'ISSN': ['1929-6355'],
#   'issn-type': [{'value': '1929-6355', 'type': 'electronic'}],
#   'published': {'date-parts': [[2106, 12, 6]]}},
#  {'indexed': {'date-parts': [[2024, 8, 6]],
#    'date-time': '2024-08-06T22:58:45Z',
#    'timestamp': 1722985125690},
#   'reference-count': 0,
#   'publisher': 'Valley International',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['ijetst'],
#   'DOI': '10.18535/ijetst/v3i08.10',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2016, 8, 9]],
#    'date-time': '2016-08-09T07:36:43Z',
#    'timestamp': 1470728203000},
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Contour Based Real Time Multiple Object Tracking'],
#   'prefix': '10.18535',
#   'author': [{'name': 'Dept. of ECE, Channabasaveshwara Institute of Technology Gubbi, Karnataka India',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'Mrs Malleshwari',
#     'family': 'MS',
#     'sequence': 'first',
#     'affiliation': []}],
#   'member': '7803',
#   'published-online': {'date-parts': [[2106, 8, 9]]},
#   'container-title': ['International journal of Emerging Trends in Science and Technology'],
#   'original-title': ['Contour Based Real Time Multiple Object Tracking'],
#   'deposited': {'date-parts': [[2016, 8, 9]],
#    'date-time': '2016-08-09T07:36:44Z',
#    'timestamp': 1470728204000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://ijetst.in/article/v3-i8/10%20ijetst.pdf'}},
#   'issued': {'date-parts': [[2106, 8, 9]]},
#   'references-count': 0,
#   'URL': 'https://doi.org/10.18535/ijetst/v3i08.10',
#   'ISSN': ['2348-9480'],
#   'issn-type': [{'type': 'electronic', 'value': '2348-9480'}],
#   'published': {'date-parts': [[2106, 8, 9]]}},
#  {'indexed': {'date-parts': [[2025, 6, 23]],
#    'date-time': '2025-06-23T05:45:24Z',
#    'timestamp': 1750657524218},
#   'reference-count': 0,
#   'publisher': 'Impact Journals, LLC',
#   'issue': '27',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['Oncotarget'],
#   'published-print': {'date-parts': [[2106, 7, 5]]},
#   'DOI': '10.18632/oncotarget.v7i27',
#   'type': 'journal-issue',
#   'created': {'date-parts': [[2020, 7, 15]],
#    'date-time': '2020-07-15T15:15:29Z',
#    'timestamp': 1594826129000},
#   'source': 'Crossref',
#   'is-referenced-by-count': 10,
#   'prefix': '10.18632',
#   'volume': '7',
#   'member': '7892',
#   'container-title': ['Oncotarget'],
#   'language': 'en',
#   'deposited': {'date-parts': [[2020, 7, 15]],
#    'date-time': '2020-07-15T15:15:29Z',
#    'timestamp': 1594826129000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'https://www.oncotarget.com/lookup/doi/10.18632/oncotarget.v7i27'}},
#   'issued': {'date-parts': [[2106, 7, 5]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '27',
#    'published-print': {'date-parts': [[2106, 7, 5]]}},
#   'URL': 'https://doi.org/10.18632/oncotarget.v7i27',
#   'ISSN': ['1949-2553'],
#   'issn-type': [{'value': '1949-2553', 'type': 'electronic'}],
#   'published': {'date-parts': [[2106, 7, 5]]}}]

# %%
# 3. Extract license blocks, if present
#    Each item["license"] is itself a list of dicts describing one or more licenses.
all_licenses = [item.get("license", []) for item in items]
all_licenses
# Out:
# [[{'start': {'date-parts': [[2203, 10, 1]],
#     'date-time': '2203-10-01T00:00:00Z',
#     'timestamp': 7376313600000},
#    'content-version': 'tdm',
#    'delay-in-days': 0,
#    'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#  [{'start': {'date-parts': [[2203, 10, 1]],
#     'date-time': '2203-10-01T00:00:00Z',
#     'timestamp': 7376313600000},
#    'content-version': 'tdm',
#    'delay-in-days': 0,
#    'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#  [{'start': {'date-parts': [[2203, 10, 1]],
#     'date-time': '2203-10-01T00:00:00Z',
#     'timestamp': 7376313600000},
#    'content-version': 'tdm',
#    'delay-in-days': 0,
#    'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#  [{'start': {'date-parts': [[2203, 10, 1]],
#     'date-time': '2203-10-01T00:00:00Z',
#     'timestamp': 7376313600000},
#    'content-version': 'tdm',
#    'delay-in-days': 0,
#    'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#  [{'start': {'date-parts': [[2203, 10, 1]],
#     'date-time': '2203-10-01T00:00:00Z',
#     'timestamp': 7376313600000},
#    'content-version': 'tdm',
#    'delay-in-days': 0,
#    'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#  [{'start': {'date-parts': [[2203, 10, 1]],
#     'date-time': '2203-10-01T00:00:00Z',
#     'timestamp': 7376313600000},
#    'content-version': 'tdm',
#    'delay-in-days': 0,
#    'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#  [{'start': {'date-parts': [[2203, 10, 1]],
#     'date-time': '2203-10-01T00:00:00Z',
#     'timestamp': 7376313600000},
#    'content-version': 'tdm',
#    'delay-in-days': 0,
#    'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#  [{'start': {'date-parts': [[2203, 10, 1]],
#     'date-time': '2203-10-01T00:00:00Z',
#     'timestamp': 7376313600000},
#    'content-version': 'tdm',
#    'delay-in-days': 0,
#    'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#  [{'start': {'date-parts': [[2203, 10, 1]],
#     'date-time': '2203-10-01T00:00:00Z',
#     'timestamp': 7376313600000},
#    'content-version': 'tdm',
#    'delay-in-days': 0,
#    'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#  [{'start': {'date-parts': [[2203, 10, 1]],
#     'date-time': '2203-10-01T00:00:00Z',
#     'timestamp': 7376313600000},
#    'content-version': 'tdm',
#    'delay-in-days': 0,
#    'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#  [{'start': {'date-parts': [[2203, 10, 1]],
#     'date-time': '2203-10-01T00:00:00Z',
#     'timestamp': 7376313600000},
#    'content-version': 'tdm',
#    'delay-in-days': 0,
#    'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#  [{'start': {'date-parts': [[2203, 10, 1]],
#     'date-time': '2203-10-01T00:00:00Z',
#     'timestamp': 7376313600000},
#    'content-version': 'tdm',
#    'delay-in-days': 0,
#    'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#  [{'start': {'date-parts': [[2203, 10, 1]],
#     'date-time': '2203-10-01T00:00:00Z',
#     'timestamp': 7376313600000},
#    'content-version': 'tdm',
#    'delay-in-days': 0,
#    'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#  [{'start': {'date-parts': [[2203, 10, 1]],
#     'date-time': '2203-10-01T00:00:00Z',
#     'timestamp': 7376313600000},
#    'content-version': 'tdm',
#    'delay-in-days': 0,
#    'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#  [{'start': {'date-parts': [[2203, 10, 1]],
#     'date-time': '2203-10-01T00:00:00Z',
#     'timestamp': 7376313600000},
#    'content-version': 'tdm',
#    'delay-in-days': 0,
#    'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#  [{'start': {'date-parts': [[2203, 10, 1]],
#     'date-time': '2203-10-01T00:00:00Z',
#     'timestamp': 7376313600000},
#    'content-version': 'tdm',
#    'delay-in-days': 0,
#    'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#  [{'start': {'date-parts': [[2203, 10, 1]],
#     'date-time': '2203-10-01T00:00:00Z',
#     'timestamp': 7376313600000},
#    'content-version': 'tdm',
#    'delay-in-days': 0,
#    'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#  [{'start': {'date-parts': [[2203, 10, 1]],
#     'date-time': '2203-10-01T00:00:00Z',
#     'timestamp': 7376313600000},
#    'content-version': 'tdm',
#    'delay-in-days': 0,
#    'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#  [{'start': {'date-parts': [[2203, 10, 1]],
#     'date-time': '2203-10-01T00:00:00Z',
#     'timestamp': 7376313600000},
#    'content-version': 'tdm',
#    'delay-in-days': 0,
#    'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#  [{'start': {'date-parts': [[2203, 10, 1]],
#     'date-time': '2203-10-01T00:00:00Z',
#     'timestamp': 7376313600000},
#    'content-version': 'tdm',
#    'delay-in-days': 0,
#    'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#  [],
#  [{'start': {'date-parts': [[2023, 10, 15]],
#     'date-time': '2023-10-15T00:00:00Z',
#     'timestamp': 1697328000000},
#    'content-version': 'vor',
#    'delay-in-days': 0,
#    'URL': 'http://www.scopemed.org/?page=license'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  []]

# %%
# 4. (Optional) Flatten and pull just the URLs out
license_urls = [lic_block["URL"] for lic_list in all_licenses for lic_block in lic_list]

# %%
license_urls
# Out:
# ['https://www.elsevier.com/tdm/userlicense/1.0/',
#  'https://www.elsevier.com/tdm/userlicense/1.0/',
#  'https://www.elsevier.com/tdm/userlicense/1.0/',
#  'https://www.elsevier.com/tdm/userlicense/1.0/',
#  'https://www.elsevier.com/tdm/userlicense/1.0/',
#  'https://www.elsevier.com/tdm/userlicense/1.0/',
#  'https://www.elsevier.com/tdm/userlicense/1.0/',
#  'https://www.elsevier.com/tdm/userlicense/1.0/',
#  'https://www.elsevier.com/tdm/userlicense/1.0/',
#  'https://www.elsevier.com/tdm/userlicense/1.0/',
#  'https://www.elsevier.com/tdm/userlicense/1.0/',
#  'https://www.elsevier.com/tdm/userlicense/1.0/',
#  'https://www.elsevier.com/tdm/userlicense/1.0/',
#  'https://www.elsevier.com/tdm/userlicense/1.0/',
#  'https://www.elsevier.com/tdm/userlicense/1.0/',
#  'https://www.elsevier.com/tdm/userlicense/1.0/',
#  'https://www.elsevier.com/tdm/userlicense/1.0/',
#  'https://www.elsevier.com/tdm/userlicense/1.0/',
#  'https://www.elsevier.com/tdm/userlicense/1.0/',
#  'https://www.elsevier.com/tdm/userlicense/1.0/',
#  'http://www.scopemed.org/?page=license']

# %% [markdown]
# ### ETL for the case study

# %% [markdown]
# #### src/ingest.py

# %%
import os
import json
import requests
from datetime import datetime

# %%
# optional cell 
# adding path on both ways either we work like running pythn liek program in pythonscript.py or in interactive mode (UI) 
import os

try:
    # when running as a .py file
    ROOT = os.path.dirname(__file__)
except NameError:
    # when running in a notebook
    ROOT = os.getcwd()

RAW_DIR = os.path.join(ROOT, "data", "raw")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\milos\\OneDrive\\Programming\\15. Python\\MDPI'

# %%
RAW_DIR
# Out:
# 'data/raw'

# %%
RAW_DIR = "data/raw/"
URL = "https://api.crossref.org/works"
PARAMS = {"sort": "published", "order": "desc", "rows": 200}

# %%
# optinal
# RAW_DIR = "data/files"

# %%
def fetch_crossref():
    resp = requests.get(URL, params=PARAMS, timeout=10)
    resp.raise_for_status()
    return resp.json()["message"]["items"]

# %%
def save_raw(items):# # PuNJENJE folder path-a koji definisemo putem RAW_DIR variable 
    os.makedirs(RAW_DIR, exist_ok=True)
    for idx, item in enumerate(items, start=1):
        doi = item.get("DOI", f"no-doi-{idx}")
        # sanitize filename
        fname = doi.replace("/", "_") + ".json"
        path = os.path.join(RAW_DIR, fname)
        with open(path, "w", encoding="utf-8") as f:
            json.dump(item, f, ensure_ascii=False, indent=2)
    print(f"[{datetime.now()}] Saved {len(items)} JSON files to {RAW_DIR}")

# %%
items = fetch_crossref() # calling first function 
save_raw(items)  # calling second function on items we created by first function
# Out:
# [2025-07-01 17:43:24.949698] Saved 200 JSON files to data/files

# %%
type(items)
# Out:
# list

# %%
items
# Out:
# [{'indexed': {'date-parts': [[2022, 3, 29]],
#    'date-time': '2022-03-29T07:17:11Z',
#    'timestamp': 1648538231791},
#   'reference-count': 0,
#   'publisher': 'Elsevier BV',
#   'issue': '7',
#   'license': [{'start': {'date-parts': [[2203, 10, 1]],
#      'date-time': '2203-10-01T00:00:00Z',
#      'timestamp': 7376313600000},
#     'content-version': 'tdm',
#     'delay-in-days': 0,
#     'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['Aten Primaria'],
#   'published-print': {'date-parts': [[2203, 10]]},
#   'DOI': '10.1157/13053457',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2003, 11, 17]],
#    'date-time': '2003-11-17T16:44:58Z',
#    'timestamp': 1069087498000},
#   'page': '437-437',
#   'source': 'Crossref',
#   'is-referenced-by-count': 1,
#   'title': ['Prevalencia del uso preconcepcional del ácido fólico en el área norte de Pontevedra'],
#   'prefix': '10.1016',
#   'volume': '32',
#   'author': [{'given': 'A',
#     'family': 'Pérez-Vázquez',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'R',
#     'family': 'Vidal Álvarez',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'M',
#     'family': 'Castro Pazos',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'A',
#     'family': 'Aulet Ruiz',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '78',
#   'container-title': ['Atención Primaria'],
#   'link': [{'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/xml',
#     'content-type': 'text/xml',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'},
#    {'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/plain',
#     'content-type': 'text/plain',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'}],
#   'deposited': {'date-parts': [[2019, 2, 17]],
#    'date-time': '2019-02-17T01:23:25Z',
#    'timestamp': 1550366605000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://db.doyma.es/cgi-bin/wdbcgi.exe/doyma/mrevista.fulltext?pident=13053457'}},
#   'issued': {'date-parts': [[2203, 10]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '7'},
#   'alternative-id': ['13002413'],
#   'URL': 'https://doi.org/10.1157/13053457',
#   'ISSN': ['0212-6567', '1578-1275'],
#   'issn-type': [{'value': '0212-6567', 'type': 'print'},
#    {'value': '1578-1275', 'type': 'electronic'}],
#   'published': {'date-parts': [[2203, 10]]}},
#  {'indexed': {'date-parts': [[2022, 4, 1]],
#    'date-time': '2022-04-01T11:13:10Z',
#    'timestamp': 1648811590450},
#   'reference-count': 0,
#   'publisher': 'Elsevier BV',
#   'issue': '7',
#   'license': [{'start': {'date-parts': [[2203, 10, 1]],
#      'date-time': '2203-10-01T00:00:00Z',
#      'timestamp': 7376313600000},
#     'content-version': 'tdm',
#     'delay-in-days': 0,
#     'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['Aten Primaria'],
#   'published-print': {'date-parts': [[2203, 10]]},
#   'DOI': '10.1157/13053459',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2003, 11, 17]],
#    'date-time': '2003-11-17T16:44:58Z',
#    'timestamp': 1069087498000},
#   'page': '435b-435',
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Mastopatía tras tratamiento con estradiol y pantoprazol'],
#   'prefix': '10.1016',
#   'volume': '32',
#   'author': [{'given': 'A',
#     'family': 'Piedra Cerezal',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'L',
#     'family': 'Sánchez Álvarez',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'G',
#     'family': 'Manso Rodríguez',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'A',
#     'family': 'Hidalgo Balsera',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '78',
#   'container-title': ['Atención Primaria'],
#   'link': [{'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/xml',
#     'content-type': 'text/xml',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'},
#    {'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/plain',
#     'content-type': 'text/plain',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'}],
#   'deposited': {'date-parts': [[2019, 2, 17]],
#    'date-time': '2019-02-17T01:23:25Z',
#    'timestamp': 1550366605000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://db.doyma.es/cgi-bin/wdbcgi.exe/doyma/mrevista.fulltext?pident=13053459'}},
#   'issued': {'date-parts': [[2203, 10]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '7'},
#   'alternative-id': ['13002413'],
#   'URL': 'https://doi.org/10.1157/13053459',
#   'ISSN': ['0212-6567', '1578-1275'],
#   'issn-type': [{'value': '0212-6567', 'type': 'print'},
#    {'value': '1578-1275', 'type': 'electronic'}],
#   'published': {'date-parts': [[2203, 10]]}},
#  {'indexed': {'date-parts': [[2022, 4, 2]],
#    'date-time': '2022-04-02T08:47:24Z',
#    'timestamp': 1648889244489},
#   'reference-count': 0,
#   'publisher': 'Elsevier BV',
#   'issue': '7',
#   'license': [{'start': {'date-parts': [[2203, 10, 1]],
#      'date-time': '2203-10-01T00:00:00Z',
#      'timestamp': 7376313600000},
#     'content-version': 'tdm',
#     'delay-in-days': 0,
#     'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['Aten Primaria'],
#   'published-print': {'date-parts': [[2203, 10]]},
#   'DOI': '10.1157/13053456',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2003, 11, 17]],
#    'date-time': '2003-11-17T16:44:58Z',
#    'timestamp': 1069087498000},
#   'page': '438b-438',
#   'source': 'Crossref',
#   'is-referenced-by-count': 1,
#   'title': ['Sonambulismo asociado con zolpidem'],
#   'prefix': '10.1016',
#   'volume': '32',
#   'author': [{'given': 'M',
#     'family': 'Yanes Baonza',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'JM',
#     'family': 'Ferrer García-Borrás',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'A',
#     'family': 'Cabrera Majada',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'R',
#     'family': 'Sánchez González',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '78',
#   'container-title': ['Atención Primaria'],
#   'link': [{'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/xml',
#     'content-type': 'text/xml',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'},
#    {'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/plain',
#     'content-type': 'text/plain',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'}],
#   'deposited': {'date-parts': [[2019, 2, 17]],
#    'date-time': '2019-02-17T01:23:25Z',
#    'timestamp': 1550366605000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://db.doyma.es/cgi-bin/wdbcgi.exe/doyma/mrevista.fulltext?pident=13053456'}},
#   'issued': {'date-parts': [[2203, 10]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '7'},
#   'alternative-id': ['13002413'],
#   'URL': 'https://doi.org/10.1157/13053456',
#   'ISSN': ['0212-6567', '1578-1275'],
#   'issn-type': [{'value': '0212-6567', 'type': 'print'},
#    {'value': '1578-1275', 'type': 'electronic'}],
#   'published': {'date-parts': [[2203, 10]]}},
#  {'indexed': {'date-parts': [[2022, 4, 5]],
#    'date-time': '2022-04-05T10:39:27Z',
#    'timestamp': 1649155167162},
#   'reference-count': 0,
#   'publisher': 'Elsevier BV',
#   'issue': '7',
#   'license': [{'start': {'date-parts': [[2203, 10, 1]],
#      'date-time': '2203-10-01T00:00:00Z',
#      'timestamp': 7376313600000},
#     'content-version': 'tdm',
#     'delay-in-days': 0,
#     'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['Aten Primaria'],
#   'published-print': {'date-parts': [[2203, 10]]},
#   'DOI': '10.1157/13053452',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2003, 11, 17]],
#    'date-time': '2003-11-17T11:44:58Z',
#    'timestamp': 1069069498000},
#   'page': '440-440',
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Respuesta de la autora'],
#   'prefix': '10.1016',
#   'volume': '32',
#   'author': [{'given': 'I',
#     'family': 'Fernández Fernández',
#     'sequence': 'first',
#     'affiliation': []}],
#   'member': '78',
#   'container-title': ['Atención Primaria'],
#   'link': [{'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/xml',
#     'content-type': 'text/xml',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'},
#    {'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/plain',
#     'content-type': 'text/plain',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'}],
#   'deposited': {'date-parts': [[2019, 2, 16]],
#    'date-time': '2019-02-16T20:23:25Z',
#    'timestamp': 1550348605000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://db.doyma.es/cgi-bin/wdbcgi.exe/doyma/mrevista.fulltext?pident=13053452'}},
#   'issued': {'date-parts': [[2203, 10]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '7'},
#   'alternative-id': ['13002413'],
#   'URL': 'https://doi.org/10.1157/13053452',
#   'ISSN': ['0212-6567', '1578-1275'],
#   'issn-type': [{'value': '0212-6567', 'type': 'print'},
#    {'value': '1578-1275', 'type': 'electronic'}],
#   'published': {'date-parts': [[2203, 10]]}},
#  {'indexed': {'date-parts': [[2022, 3, 31]],
#    'date-time': '2022-03-31T07:19:57Z',
#    'timestamp': 1648711197444},
#   'reference-count': 0,
#   'publisher': 'Elsevier BV',
#   'issue': '7',
#   'license': [{'start': {'date-parts': [[2203, 10, 1]],
#      'date-time': '2203-10-01T00:00:00Z',
#      'timestamp': 7376313600000},
#     'content-version': 'tdm',
#     'delay-in-days': 0,
#     'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['Aten Primaria'],
#   'published-print': {'date-parts': [[2203, 10]]},
#   'DOI': '10.1157/13053449',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2003, 11, 17]],
#    'date-time': '2003-11-17T16:44:58Z',
#    'timestamp': 1069087498000},
#   'page': '441-441',
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Hepatitis C: diagnóstico y prevención desde la consulta de atención primaria'],
#   'prefix': '10.1016',
#   'volume': '32',
#   'author': [{'given': 'JI',
#     'family': 'Alastrué Loscos',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'M',
#     'family': 'Giner Valero',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'FJ',
#     'family': 'Beltrán Armada',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '78',
#   'container-title': ['Atención Primaria'],
#   'link': [{'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/xml',
#     'content-type': 'text/xml',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'},
#    {'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/plain',
#     'content-type': 'text/plain',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'}],
#   'deposited': {'date-parts': [[2019, 2, 17]],
#    'date-time': '2019-02-17T01:23:25Z',
#    'timestamp': 1550366605000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://db.doyma.es/cgi-bin/wdbcgi.exe/doyma/mrevista.fulltext?pident=13053449'}},
#   'issued': {'date-parts': [[2203, 10]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '7'},
#   'alternative-id': ['13002413'],
#   'URL': 'https://doi.org/10.1157/13053449',
#   'ISSN': ['0212-6567', '1578-1275'],
#   'issn-type': [{'value': '0212-6567', 'type': 'print'},
#    {'value': '1578-1275', 'type': 'electronic'}],
#   'published': {'date-parts': [[2203, 10]]}},
#  {'indexed': {'date-parts': [[2022, 4, 3]],
#    'date-time': '2022-04-03T20:51:47Z',
#    'timestamp': 1649019107577},
#   'reference-count': 0,
#   'publisher': 'Elsevier BV',
#   'issue': '7',
#   'license': [{'start': {'date-parts': [[2203, 10, 1]],
#      'date-time': '2203-10-01T00:00:00Z',
#      'timestamp': 7376313600000},
#     'content-version': 'tdm',
#     'delay-in-days': 0,
#     'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['Aten Primaria'],
#   'published-print': {'date-parts': [[2203, 10]]},
#   'DOI': '10.1157/13053460',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2003, 11, 17]],
#    'date-time': '2003-11-17T11:44:58Z',
#    'timestamp': 1069069498000},
#   'page': '434-434',
#   'source': 'Crossref',
#   'is-referenced-by-count': 1,
#   'title': ['Intoxicación por paracetamol líquidoen menores de 6 años: cambios en la dosis tóxica'],
#   'prefix': '10.1016',
#   'volume': '32',
#   'author': [{'given': 'E',
#     'family': 'Garcés Redolat',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'A',
#     'family': 'Parra Hernández',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'P',
#     'family': 'Munné Mas',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'G',
#     'family': 'Burillo-Putze',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '78',
#   'container-title': ['Atención Primaria'],
#   'link': [{'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/xml',
#     'content-type': 'text/xml',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'},
#    {'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/plain',
#     'content-type': 'text/plain',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'}],
#   'deposited': {'date-parts': [[2019, 2, 16]],
#    'date-time': '2019-02-16T20:23:25Z',
#    'timestamp': 1550348605000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://db.doyma.es/cgi-bin/wdbcgi.exe/doyma/mrevista.fulltext?pident=13053460'}},
#   'issued': {'date-parts': [[2203, 10]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '7'},
#   'alternative-id': ['13002413'],
#   'URL': 'https://doi.org/10.1157/13053460',
#   'ISSN': ['0212-6567', '1578-1275'],
#   'issn-type': [{'value': '0212-6567', 'type': 'print'},
#    {'value': '1578-1275', 'type': 'electronic'}],
#   'published': {'date-parts': [[2203, 10]]}},
#  {'indexed': {'date-parts': [[2022, 3, 30]],
#    'date-time': '2022-03-30T21:56:26Z',
#    'timestamp': 1648677386051},
#   'reference-count': 0,
#   'publisher': 'Elsevier BV',
#   'issue': '7',
#   'license': [{'start': {'date-parts': [[2203, 10, 1]],
#      'date-time': '2203-10-01T00:00:00Z',
#      'timestamp': 7376313600000},
#     'content-version': 'tdm',
#     'delay-in-days': 0,
#     'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['Aten Primaria'],
#   'published-print': {'date-parts': [[2203, 10]]},
#   'DOI': '10.1157/13053448',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2003, 11, 17]],
#    'date-time': '2003-11-17T16:44:58Z',
#    'timestamp': 1069087498000},
#   'page': '442-443',
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Respuesta de los autores'],
#   'prefix': '10.1016',
#   'volume': '32',
#   'author': [{'given': 'M.A',
#     'family': 'Martínez Adell',
#     'sequence': 'first',
#     'affiliation': []}],
#   'member': '78',
#   'container-title': ['Atención Primaria'],
#   'link': [{'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/xml',
#     'content-type': 'text/xml',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'},
#    {'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/plain',
#     'content-type': 'text/plain',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'}],
#   'deposited': {'date-parts': [[2019, 2, 17]],
#    'date-time': '2019-02-17T01:23:25Z',
#    'timestamp': 1550366605000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://db.doyma.es/cgi-bin/wdbcgi.exe/doyma/mrevista.fulltext?pident=13053448'}},
#   'issued': {'date-parts': [[2203, 10]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '7'},
#   'alternative-id': ['13002413'],
#   'URL': 'https://doi.org/10.1157/13053448',
#   'ISSN': ['0212-6567', '1578-1275'],
#   'issn-type': [{'value': '0212-6567', 'type': 'print'},
#    {'value': '1578-1275', 'type': 'electronic'}],
#   'published': {'date-parts': [[2203, 10]]}},
#  {'indexed': {'date-parts': [[2022, 4, 4]],
#    'date-time': '2022-04-04T05:42:24Z',
#    'timestamp': 1649050944707},
#   'reference-count': 0,
#   'publisher': 'Elsevier BV',
#   'issue': '7',
#   'license': [{'start': {'date-parts': [[2203, 10, 1]],
#      'date-time': '2203-10-01T00:00:00Z',
#      'timestamp': 7376313600000},
#     'content-version': 'tdm',
#     'delay-in-days': 0,
#     'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['Aten Primaria'],
#   'published-print': {'date-parts': [[2203, 10]]},
#   'DOI': '10.1157/13053451',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2003, 11, 17]],
#    'date-time': '2003-11-17T11:44:58Z',
#    'timestamp': 1069069498000},
#   'page': '441b-441',
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Prevalencia de hepatitis A y hepatopatías crónicas: un reto a desarrollar'],
#   'prefix': '10.1016',
#   'volume': '32',
#   'author': [{'given': 'P',
#     'family': 'Bachiller Luque',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'C',
#     'family': 'Navarro Cañadas',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'A',
#     'family': 'Almaraz Gómez',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'A',
#     'family': 'Orduña Domingo',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '78',
#   'container-title': ['Atención Primaria'],
#   'link': [{'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/xml',
#     'content-type': 'text/xml',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'},
#    {'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/plain',
#     'content-type': 'text/plain',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'}],
#   'deposited': {'date-parts': [[2019, 2, 16]],
#    'date-time': '2019-02-16T20:23:25Z',
#    'timestamp': 1550348605000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://db.doyma.es/cgi-bin/wdbcgi.exe/doyma/mrevista.fulltext?pident=13053451'}},
#   'issued': {'date-parts': [[2203, 10]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '7'},
#   'alternative-id': ['13002413'],
#   'URL': 'https://doi.org/10.1157/13053451',
#   'ISSN': ['0212-6567', '1578-1275'],
#   'issn-type': [{'value': '0212-6567', 'type': 'print'},
#    {'value': '1578-1275', 'type': 'electronic'}],
#   'published': {'date-parts': [[2203, 10]]}},
#  {'indexed': {'date-parts': [[2022, 4, 5]],
#    'date-time': '2022-04-05T07:18:43Z',
#    'timestamp': 1649143123538},
#   'reference-count': 0,
#   'publisher': 'Elsevier BV',
#   'issue': '7',
#   'license': [{'start': {'date-parts': [[2203, 10, 1]],
#      'date-time': '2203-10-01T00:00:00Z',
#      'timestamp': 7376313600000},
#     'content-version': 'tdm',
#     'delay-in-days': 0,
#     'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['Aten Primaria'],
#   'published-print': {'date-parts': [[2203, 10]]},
#   'DOI': '10.1157/13053458',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2003, 11, 17]],
#    'date-time': '2003-11-17T11:44:58Z',
#    'timestamp': 1069069498000},
#   'page': '435-436',
#   'source': 'Crossref',
#   'is-referenced-by-count': 5,
#   'title': ['La espirometría en el diagnóstico de la enfermedad pulmonar obstructiva crónica en atención primaria'],
#   'prefix': '10.1016',
#   'volume': '32',
#   'author': [{'given': 'JM',
#     'family': 'Manresa Presasa',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'J',
#     'family': 'Rebull Fatsinib',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'M',
#     'family': 'Miravalls Figuerolac',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'R',
#     'family': 'Caballol Angelatsd',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'P',
#     'family': 'Minué Magañae',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'R',
#     'family': 'Juan Franquetf',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '78',
#   'container-title': ['Atención Primaria'],
#   'link': [{'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/xml',
#     'content-type': 'text/xml',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'},
#    {'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/plain',
#     'content-type': 'text/plain',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'}],
#   'deposited': {'date-parts': [[2019, 2, 16]],
#    'date-time': '2019-02-16T20:23:25Z',
#    'timestamp': 1550348605000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://db.doyma.es/cgi-bin/wdbcgi.exe/doyma/mrevista.fulltext?pident=13053458'}},
#   'issued': {'date-parts': [[2203, 10]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '7'},
#   'alternative-id': ['13002413'],
#   'URL': 'https://doi.org/10.1157/13053458',
#   'ISSN': ['0212-6567', '1578-1275'],
#   'issn-type': [{'value': '0212-6567', 'type': 'print'},
#    {'value': '1578-1275', 'type': 'electronic'}],
#   'published': {'date-parts': [[2203, 10]]}},
#  {'indexed': {'date-parts': [[2024, 9, 16]],
#    'date-time': '2024-09-16T08:36:35Z',
#    'timestamp': 1726475795023},
#   'reference-count': 0,
#   'publisher': 'Elsevier BV',
#   'issue': '7',
#   'license': [{'start': {'date-parts': [[2203, 10, 1]],
#      'date-time': '2203-10-01T00:00:00Z',
#      'timestamp': 7376313600000},
#     'content-version': 'tdm',
#     'delay-in-days': 0,
#     'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['Aten Primaria'],
#   'published-print': {'date-parts': [[2203, 10]]},
#   'DOI': '10.1157/13053723',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2003, 11, 17]],
#    'date-time': '2003-11-17T11:44:58Z',
#    'timestamp': 1069069498000},
#   'page': '423-424',
#   'source': 'Crossref',
#   'is-referenced-by-count': 19,
#   'title': ['Análisis de la demanda en los servicios de urgencias de Barcelona'],
#   'prefix': '10.1016',
#   'volume': '32',
#   'author': [{'given': 'E',
#     'family': 'Torné Vilagrasa',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'A',
#     'family': 'Guarga Rojas',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'MG',
#     'family': 'Torras Boatella',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'A',
#     'family': 'Pozuelo García',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'M',
#     'family': 'Pasarin Rua',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'C',
#     'family': 'Borrell Thió',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '78',
#   'container-title': ['Atención Primaria'],
#   'link': [{'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/xml',
#     'content-type': 'text/xml',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'},
#    {'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/plain',
#     'content-type': 'text/plain',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'}],
#   'deposited': {'date-parts': [[2019, 2, 16]],
#    'date-time': '2019-02-16T20:23:25Z',
#    'timestamp': 1550348605000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://db.doyma.es/cgi-bin/wdbcgi.exe/doyma/mrevista.fulltext?pident=13053723'}},
#   'issued': {'date-parts': [[2203, 10]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '7'},
#   'alternative-id': ['13002413'],
#   'URL': 'https://doi.org/10.1157/13053723',
#   'ISSN': ['0212-6567', '1578-1275'],
#   'issn-type': [{'value': '0212-6567', 'type': 'print'},
#    {'value': '1578-1275', 'type': 'electronic'}],
#   'published': {'date-parts': [[2203, 10]]}},
#  {'indexed': {'date-parts': [[2022, 4, 2]],
#    'date-time': '2022-04-02T11:41:51Z',
#    'timestamp': 1648899711308},
#   'reference-count': 0,
#   'publisher': 'Elsevier BV',
#   'issue': '7',
#   'license': [{'start': {'date-parts': [[2203, 10, 1]],
#      'date-time': '2203-10-01T00:00:00Z',
#      'timestamp': 7376313600000},
#     'content-version': 'tdm',
#     'delay-in-days': 0,
#     'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['Aten Primaria'],
#   'published-print': {'date-parts': [[2203, 10]]},
#   'DOI': '10.1157/13053468',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2003, 11, 17]],
#    'date-time': '2003-11-17T16:44:58Z',
#    'timestamp': 1069087498000},
#   'page': '401-402',
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Una apuesta por la calidad, la seriedad y la independencia científica'],
#   'prefix': '10.1016',
#   'volume': '32',
#   'author': [{'given': 'M',
#     'family': 'Ferran Mercadé',
#     'sequence': 'first',
#     'affiliation': []}],
#   'member': '78',
#   'container-title': ['Atención Primaria'],
#   'link': [{'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/xml',
#     'content-type': 'text/xml',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'},
#    {'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/plain',
#     'content-type': 'text/plain',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'}],
#   'deposited': {'date-parts': [[2019, 2, 17]],
#    'date-time': '2019-02-17T01:23:25Z',
#    'timestamp': 1550366605000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://db.doyma.es/cgi-bin/wdbcgi.exe/doyma/mrevista.fulltext?pident=13053468'}},
#   'issued': {'date-parts': [[2203, 10]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '7'},
#   'alternative-id': ['13002413'],
#   'URL': 'https://doi.org/10.1157/13053468',
#   'ISSN': ['0212-6567', '1578-1275'],
#   'issn-type': [{'value': '0212-6567', 'type': 'print'},
#    {'value': '1578-1275', 'type': 'electronic'}],
#   'published': {'date-parts': [[2203, 10]]}},
#  {'indexed': {'date-parts': [[2025, 5, 30]],
#    'date-time': '2025-05-30T05:22:24Z',
#    'timestamp': 1748582544347},
#   'reference-count': 0,
#   'publisher': 'Elsevier BV',
#   'issue': '7',
#   'license': [{'start': {'date-parts': [[2203, 10, 1]],
#      'date-time': '2203-10-01T00:00:00Z',
#      'timestamp': 7376313600000},
#     'content-version': 'tdm',
#     'delay-in-days': 0,
#     'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['Aten Primaria'],
#   'published-print': {'date-parts': [[2203, 10]]},
#   'DOI': '10.1157/13053466',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2003, 11, 17]],
#    'date-time': '2003-11-17T16:44:58Z',
#    'timestamp': 1069087498000},
#   'page': '408-409',
#   'source': 'Crossref',
#   'is-referenced-by-count': 1,
#   'title': ['Comentario: Prevención de los factores de riesgo de los trastornos de la conducta alimentaria en adolescentes:'],
#   'prefix': '10.1016',
#   'volume': '32',
#   'author': [{'given': 'P.J',
#     'family': 'Ruiz Lázaro',
#     'sequence': 'first',
#     'affiliation': []}],
#   'member': '78',
#   'container-title': ['Atención Primaria'],
#   'link': [{'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/xml',
#     'content-type': 'text/xml',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'},
#    {'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/plain',
#     'content-type': 'text/plain',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'}],
#   'deposited': {'date-parts': [[2019, 2, 17]],
#    'date-time': '2019-02-17T01:23:25Z',
#    'timestamp': 1550366605000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://db.doyma.es/cgi-bin/wdbcgi.exe/doyma/mrevista.fulltext?pident=13053466'}},
#   'issued': {'date-parts': [[2203, 10]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '7'},
#   'alternative-id': ['13002413'],
#   'URL': 'https://doi.org/10.1157/13053466',
#   'ISSN': ['0212-6567', '1578-1275'],
#   'issn-type': [{'value': '0212-6567', 'type': 'print'},
#    {'value': '1578-1275', 'type': 'electronic'}],
#   'published': {'date-parts': [[2203, 10]]}},
#  {'indexed': {'date-parts': [[2022, 3, 29]],
#    'date-time': '2022-03-29T22:52:50Z',
#    'timestamp': 1648594370459},
#   'reference-count': 0,
#   'publisher': 'Elsevier BV',
#   'issue': '7',
#   'license': [{'start': {'date-parts': [[2203, 10, 1]],
#      'date-time': '2203-10-01T00:00:00Z',
#      'timestamp': 7376313600000},
#     'content-version': 'tdm',
#     'delay-in-days': 0,
#     'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['Aten Primaria'],
#   'published-print': {'date-parts': [[2203, 10]]},
#   'DOI': '10.1157/13053453',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2003, 11, 17]],
#    'date-time': '2003-11-17T11:44:58Z',
#    'timestamp': 1069069498000},
#   'page': '439-439',
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Profundizando en los porqués y los cómos de la investigación en atención primaria'],
#   'prefix': '10.1016',
#   'volume': '32',
#   'author': [{'given': 'MA',
#     'family': 'Prieto Rodríguez',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'JC',
#     'family': 'March Cerdá',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '78',
#   'container-title': ['Atención Primaria'],
#   'link': [{'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/xml',
#     'content-type': 'text/xml',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'},
#    {'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/plain',
#     'content-type': 'text/plain',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'}],
#   'deposited': {'date-parts': [[2019, 2, 16]],
#    'date-time': '2019-02-16T20:23:25Z',
#    'timestamp': 1550348605000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://db.doyma.es/cgi-bin/wdbcgi.exe/doyma/mrevista.fulltext?pident=13053453'}},
#   'issued': {'date-parts': [[2203, 10]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '7'},
#   'alternative-id': ['13002413'],
#   'URL': 'https://doi.org/10.1157/13053453',
#   'ISSN': ['0212-6567', '1578-1275'],
#   'issn-type': [{'value': '0212-6567', 'type': 'print'},
#    {'value': '1578-1275', 'type': 'electronic'}],
#   'published': {'date-parts': [[2203, 10]]}},
#  {'indexed': {'date-parts': [[2022, 3, 28]],
#    'date-time': '2022-03-28T21:30:50Z',
#    'timestamp': 1648503050273},
#   'reference-count': 0,
#   'publisher': 'Elsevier BV',
#   'issue': '7',
#   'license': [{'start': {'date-parts': [[2203, 10, 1]],
#      'date-time': '2203-10-01T00:00:00Z',
#      'timestamp': 7376313600000},
#     'content-version': 'tdm',
#     'delay-in-days': 0,
#     'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['Aten Primaria'],
#   'published-print': {'date-parts': [[2203, 10]]},
#   'DOI': '10.1157/13053455',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2003, 11, 17]],
#    'date-time': '2003-11-17T16:44:58Z',
#    'timestamp': 1069087498000},
#   'page': '438-438',
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Síndrome de latigazo cervical y pruebas radiológicas'],
#   'prefix': '10.1016',
#   'volume': '32',
#   'author': [{'given': 'G',
#     'family': 'Burillo-Putze',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'JM',
#     'family': 'Osuna Peña',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'V',
#     'family': 'García Marín',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'N',
#     'family': 'García Marín',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '78',
#   'container-title': ['Atención Primaria'],
#   'link': [{'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/xml',
#     'content-type': 'text/xml',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'},
#    {'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/plain',
#     'content-type': 'text/plain',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'}],
#   'deposited': {'date-parts': [[2019, 2, 17]],
#    'date-time': '2019-02-17T01:23:25Z',
#    'timestamp': 1550366605000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://db.doyma.es/cgi-bin/wdbcgi.exe/doyma/mrevista.fulltext?pident=13053455'}},
#   'issued': {'date-parts': [[2203, 10]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '7'},
#   'alternative-id': ['13002413'],
#   'URL': 'https://doi.org/10.1157/13053455',
#   'ISSN': ['0212-6567', '1578-1275'],
#   'issn-type': [{'value': '0212-6567', 'type': 'print'},
#    {'value': '1578-1275', 'type': 'electronic'}],
#   'published': {'date-parts': [[2203, 10]]}},
#  {'indexed': {'date-parts': [[2022, 4, 2]],
#    'date-time': '2022-04-02T04:30:17Z',
#    'timestamp': 1648873817605},
#   'reference-count': 0,
#   'publisher': 'Elsevier BV',
#   'issue': '7',
#   'license': [{'start': {'date-parts': [[2203, 10, 1]],
#      'date-time': '2203-10-01T00:00:00Z',
#      'timestamp': 7376313600000},
#     'content-version': 'tdm',
#     'delay-in-days': 0,
#     'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['Aten Primaria'],
#   'published-print': {'date-parts': [[2203, 10]]},
#   'DOI': '10.1157/13053467',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2003, 11, 17]],
#    'date-time': '2003-11-17T16:44:58Z',
#    'timestamp': 1069087498000},
#   'page': '403-407',
#   'source': 'Crossref',
#   'is-referenced-by-count': 1,
#   'title': ['Factores de riesgo relacionados con trastornos en la conducta alimentaria en una comunidad de escolares'],
#   'prefix': '10.1016',
#   'volume': '32',
#   'author': [{'given': 'M',
#     'family': 'Díaz Benavente',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'F',
#     'family': 'Rodríguez Morilla',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'C',
#     'family': 'Martín Leal',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'MV',
#     'family': 'Hiruela Benjumea',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '78',
#   'container-title': ['Atención Primaria'],
#   'link': [{'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/xml',
#     'content-type': 'text/xml',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'},
#    {'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/plain',
#     'content-type': 'text/plain',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'}],
#   'deposited': {'date-parts': [[2019, 2, 17]],
#    'date-time': '2019-02-17T01:23:25Z',
#    'timestamp': 1550366605000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://db.doyma.es/cgi-bin/wdbcgi.exe/doyma/mrevista.fulltext?pident=13053467'}},
#   'issued': {'date-parts': [[2203, 10]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '7'},
#   'alternative-id': ['13002413'],
#   'URL': 'https://doi.org/10.1157/13053467',
#   'ISSN': ['0212-6567', '1578-1275'],
#   'issn-type': [{'value': '0212-6567', 'type': 'print'},
#    {'value': '1578-1275', 'type': 'electronic'}],
#   'published': {'date-parts': [[2203, 10]]}},
#  {'indexed': {'date-parts': [[2022, 4, 1]],
#    'date-time': '2022-04-01T03:47:35Z',
#    'timestamp': 1648784855935},
#   'reference-count': 0,
#   'publisher': 'Elsevier BV',
#   'issue': '7',
#   'license': [{'start': {'date-parts': [[2203, 10, 1]],
#      'date-time': '2203-10-01T00:00:00Z',
#      'timestamp': 7376313600000},
#     'content-version': 'tdm',
#     'delay-in-days': 0,
#     'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['Aten Primaria'],
#   'published-print': {'date-parts': [[2203, 10]]},
#   'DOI': '10.1157/13053454',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2003, 11, 17]],
#    'date-time': '2003-11-17T16:44:58Z',
#    'timestamp': 1069087498000},
#   'page': '439b-439',
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Respuesta de los autores'],
#   'prefix': '10.1016',
#   'volume': '32',
#   'author': [{'given': 'S',
#     'family': 'Castiella',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'MA',
#     'family': 'López Vázquez',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '78',
#   'container-title': ['Atención Primaria'],
#   'link': [{'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/xml',
#     'content-type': 'text/xml',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'},
#    {'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/plain',
#     'content-type': 'text/plain',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'}],
#   'deposited': {'date-parts': [[2019, 2, 17]],
#    'date-time': '2019-02-17T01:23:25Z',
#    'timestamp': 1550366605000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://db.doyma.es/cgi-bin/wdbcgi.exe/doyma/mrevista.fulltext?pident=13053454'}},
#   'issued': {'date-parts': [[2203, 10]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '7'},
#   'alternative-id': ['13002413'],
#   'URL': 'https://doi.org/10.1157/13053454',
#   'ISSN': ['0212-6567', '1578-1275'],
#   'issn-type': [{'value': '0212-6567', 'type': 'print'},
#    {'value': '1578-1275', 'type': 'electronic'}],
#   'published': {'date-parts': [[2203, 10]]}},
#  {'indexed': {'date-parts': [[2022, 4, 5]],
#    'date-time': '2022-04-05T06:07:38Z',
#    'timestamp': 1649138858401},
#   'reference-count': 0,
#   'publisher': 'Elsevier BV',
#   'issue': '7',
#   'license': [{'start': {'date-parts': [[2203, 10, 1]],
#      'date-time': '2203-10-01T00:00:00Z',
#      'timestamp': 7376313600000},
#     'content-version': 'tdm',
#     'delay-in-days': 0,
#     'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['Aten Primaria'],
#   'published-print': {'date-parts': [[2203, 10]]},
#   'DOI': '10.1157/13053463',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2003, 11, 17]],
#    'date-time': '2003-11-17T11:44:58Z',
#    'timestamp': 1069069498000},
#   'page': '420-422',
#   'source': 'Crossref',
#   'is-referenced-by-count': 5,
#   'title': ['El riesgo coronario en España y el tratamiento con fármacos hipolipemiantes'],
#   'prefix': '10.1016',
#   'volume': '32',
#   'author': [{'given': 'A',
#     'family': 'Maiques Galán',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'F',
#     'family': 'Villar Álvarez',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'C',
#     'family': 'Llor Vila',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'J',
#     'family': 'Torcal Laguna',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '78',
#   'container-title': ['Atención Primaria'],
#   'link': [{'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/xml',
#     'content-type': 'text/xml',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'},
#    {'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/plain',
#     'content-type': 'text/plain',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'}],
#   'deposited': {'date-parts': [[2019, 2, 16]],
#    'date-time': '2019-02-16T20:23:25Z',
#    'timestamp': 1550348605000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://db.doyma.es/cgi-bin/wdbcgi.exe/doyma/mrevista.fulltext?pident=13053463'}},
#   'issued': {'date-parts': [[2203, 10]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '7'},
#   'alternative-id': ['13002413'],
#   'URL': 'https://doi.org/10.1157/13053463',
#   'ISSN': ['0212-6567', '1578-1275'],
#   'issn-type': [{'value': '0212-6567', 'type': 'print'},
#    {'value': '1578-1275', 'type': 'electronic'}],
#   'published': {'date-parts': [[2203, 10]]}},
#  {'indexed': {'date-parts': [[2022, 4, 4]],
#    'date-time': '2022-04-04T14:54:36Z',
#    'timestamp': 1649084076462},
#   'reference-count': 0,
#   'publisher': 'Elsevier BV',
#   'issue': '7',
#   'license': [{'start': {'date-parts': [[2203, 10, 1]],
#      'date-time': '2203-10-01T00:00:00Z',
#      'timestamp': 7376313600000},
#     'content-version': 'tdm',
#     'delay-in-days': 0,
#     'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['Aten Primaria'],
#   'published-print': {'date-parts': [[2203, 10]]},
#   'DOI': '10.1157/13053461',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2003, 11, 17]],
#    'date-time': '2003-11-17T16:44:58Z',
#    'timestamp': 1069087498000},
#   'page': '425-433',
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Violencia en la pareja: papel del médico de familia'],
#   'prefix': '10.1016',
#   'volume': '32',
#   'author': [{'given': 'MC',
#     'family': 'Fernández Alonso',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'S',
#     'family': 'Herrero Velázquez',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'F',
#     'family': 'Buitrago Ramírez',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'R',
#     'family': 'Ciurana Misol',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'L',
#     'family': 'Chocron Bentata',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'J',
#     'family': 'García Campayo',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'C',
#     'family': 'Montón Franco',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'MJ',
#     'family': 'Redondo Granado',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'MJ',
#     'family': 'Tizón García',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '78',
#   'container-title': ['Atención Primaria'],
#   'link': [{'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/xml',
#     'content-type': 'text/xml',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'},
#    {'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/plain',
#     'content-type': 'text/plain',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'}],
#   'deposited': {'date-parts': [[2019, 2, 17]],
#    'date-time': '2019-02-17T01:23:25Z',
#    'timestamp': 1550366605000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://db.doyma.es/cgi-bin/wdbcgi.exe/doyma/mrevista.fulltext?pident=13053461'}},
#   'issued': {'date-parts': [[2203, 10]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '7'},
#   'alternative-id': ['13002413'],
#   'URL': 'https://doi.org/10.1157/13053461',
#   'ISSN': ['0212-6567', '1578-1275'],
#   'issn-type': [{'value': '0212-6567', 'type': 'print'},
#    {'value': '1578-1275', 'type': 'electronic'}],
#   'published': {'date-parts': [[2203, 10]]}},
#  {'indexed': {'date-parts': [[2022, 4, 5]],
#    'date-time': '2022-04-05T10:12:58Z',
#    'timestamp': 1649153578073},
#   'reference-count': 0,
#   'publisher': 'Elsevier BV',
#   'issue': '7',
#   'license': [{'start': {'date-parts': [[2203, 10, 1]],
#      'date-time': '2203-10-01T00:00:00Z',
#      'timestamp': 7376313600000},
#     'content-version': 'tdm',
#     'delay-in-days': 0,
#     'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['Aten Primaria'],
#   'published-print': {'date-parts': [[2203, 10]]},
#   'DOI': '10.1157/13053465',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2003, 11, 17]],
#    'date-time': '2003-11-17T16:44:58Z',
#    'timestamp': 1069087498000},
#   'page': '410-414',
#   'source': 'Crossref',
#   'is-referenced-by-count': 6,
#   'title': ['Epidemiología e impacto de la incontinencia urinaria en mujeres de 40 a 65 años de edad en un área sanitaria de Madrid'],
#   'prefix': '10.1016',
#   'volume': '32',
#   'author': [{'given': 'E',
#     'family': 'Nieto Blanco',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'J',
#     'family': 'Camacho Pérez',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'V',
#     'family': 'Dávila Álvarez',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'MP',
#     'family': 'Ledo García',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'P',
#     'family': 'Moriano Bejar',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'M',
#     'family': 'Pérez Lorente',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'L',
#     'family': 'Serrano Molina',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'B',
#     'family': 'Fonseca Redondo',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '78',
#   'container-title': ['Atención Primaria'],
#   'link': [{'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/xml',
#     'content-type': 'text/xml',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'},
#    {'URL': 'https://api.elsevier.com/content/article/PII:13002413?httpAccept=text/plain',
#     'content-type': 'text/plain',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'}],
#   'deposited': {'date-parts': [[2019, 2, 17]],
#    'date-time': '2019-02-17T01:23:25Z',
#    'timestamp': 1550366605000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://db.doyma.es/cgi-bin/wdbcgi.exe/doyma/mrevista.fulltext?pident=13053465'}},
#   'issued': {'date-parts': [[2203, 10]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '7'},
#   'alternative-id': ['13002413'],
#   'URL': 'https://doi.org/10.1157/13053465',
#   'ISSN': ['0212-6567', '1578-1275'],
#   'issn-type': [{'value': '0212-6567', 'type': 'print'},
#    {'value': '1578-1275', 'type': 'electronic'}],
#   'published': {'date-parts': [[2203, 10]]}},
#  {'indexed': {'date-parts': [[2022, 4, 2]],
#    'date-time': '2022-04-02T07:20:39Z',
#    'timestamp': 1648884039449},
#   'reference-count': 0,
#   'publisher': 'Elsevier BV',
#   'issue': '7',
#   'license': [{'start': {'date-parts': [[2203, 10, 1]],
#      'date-time': '2203-10-01T00:00:00Z',
#      'timestamp': 7376313600000},
#     'content-version': 'tdm',
#     'delay-in-days': 0,
#     'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['Aten Primaria'],
#   'published-print': {'date-parts': [[2203, 10]]},
#   'DOI': '10.1157/13053464',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2003, 11, 17]],
#    'date-time': '2003-11-17T16:44:58Z',
#    'timestamp': 1069087498000},
#   'page': '415-419',
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Estudio de la marca en la prescripción de genéricos en 6 centros de salud durante el año 2001'],
#   'prefix': '10.1016',
#   'volume': '32',
#   'author': [{'given': 'G',
#     'family': 'Carmona Ibáñez',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'J',
#     'family': 'Guevara Serrano',
# ...
#   'URL': 'https://doi.org/10.12927/cjnl.2016.24988',
#   'ISSN': ['1929-6355'],
#   'issn-type': [{'value': '1929-6355', 'type': 'electronic'}],
#   'published': {'date-parts': [[2106, 12, 6]]}},
#  {'indexed': {'date-parts': [[2022, 4, 3]],
#    'date-time': '2022-04-03T05:07:34Z',
#    'timestamp': 1648962454649},
#   'reference-count': 0,
#   'publisher': 'Longwoods Publishing',
#   'issue': '4',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['CJNL'],
#   'published-print': {'date-parts': [[2106, 12, 6]]},
#   'DOI': '10.12927/cjnl.2016.24990',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2017, 4, 25]],
#    'date-time': '2017-04-25T11:08:02Z',
#    'timestamp': 1493118482000},
#   'page': '1-4',
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Looking Back and Moving Forwards'],
#   'prefix': '10.12927',
#   'volume': '29',
#   'author': [{'given': 'Lynn',
#     'family': 'Nagle',
#     'sequence': 'first',
#     'affiliation': []}],
#   'member': '5072',
#   'container-title': ['Canadian Journal of Nursing Leadership'],
#   'deposited': {'date-parts': [[2017, 4, 25]],
#    'date-time': '2017-04-25T11:08:03Z',
#    'timestamp': 1493118483000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://www.longwoods.com/content/24990'}},
#   'issued': {'date-parts': [[2106, 12, 6]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '4',
#    'published-print': {'date-parts': [[2106, 12, 6]]}},
#   'URL': 'https://doi.org/10.12927/cjnl.2016.24990',
#   'ISSN': ['1929-6355'],
#   'issn-type': [{'value': '1929-6355', 'type': 'electronic'}],
#   'published': {'date-parts': [[2106, 12, 6]]}},
#  {'indexed': {'date-parts': [[2025, 5, 26]],
#    'date-time': '2025-05-26T12:44:26Z',
#    'timestamp': 1748263466393},
#   'reference-count': 0,
#   'publisher': 'Longwoods Publishing',
#   'issue': '4',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['CJNL'],
#   'published-print': {'date-parts': [[2106, 12, 6]]},
#   'DOI': '10.12927/cjnl.2016.24983',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2017, 4, 25]],
#    'date-time': '2017-04-25T07:08:02Z',
#    'timestamp': 1493104082000},
#   'page': '59-69',
#   'source': 'Crossref',
#   'is-referenced-by-count': 7,
#   'title': ['Organizational Commitment and Nurses Characteristics as Predictors of Job Involvement'],
#   'prefix': '10.12927',
#   'volume': '29',
#   'author': [{'given': 'Kamila',
#     'family': 'Alammar',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'Mashael',
#     'family': 'Alamrani',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'Sara',
#     'family': 'Alqahtani',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'Muayyad',
#     'family': 'Ahmad',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '5072',
#   'container-title': ['Canadian Journal of Nursing Leadership'],
#   'deposited': {'date-parts': [[2017, 4, 25]],
#    'date-time': '2017-04-25T07:08:10Z',
#    'timestamp': 1493104090000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://www.longwoods.com/content/24983'}},
#   'issued': {'date-parts': [[2106, 12, 6]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '4',
#    'published-print': {'date-parts': [[2106, 12, 6]]}},
#   'URL': 'https://doi.org/10.12927/cjnl.2016.24983',
#   'ISSN': ['1929-6355'],
#   'issn-type': [{'value': '1929-6355', 'type': 'electronic'}],
#   'published': {'date-parts': [[2106, 12, 6]]}},
#  {'indexed': {'date-parts': [[2022, 3, 30]],
#    'date-time': '2022-03-30T00:23:37Z',
#    'timestamp': 1648599817681},
#   'reference-count': 0,
#   'publisher': 'Longwoods Publishing',
#   'issue': '4',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['CJNL'],
#   'published-print': {'date-parts': [[2106, 12, 6]]},
#   'DOI': '10.12927/cjnl.2016.24987',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2017, 4, 25]],
#    'date-time': '2017-04-25T11:08:02Z',
#    'timestamp': 1493118482000},
#   'page': '13-18',
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Tribute to Dr. Heather K. Spence Laschinger'],
#   'prefix': '10.12927',
#   'volume': '29',
#   'author': [{'given': 'Carol',
#     'family': 'Wong',
#     'sequence': 'first',
#     'affiliation': []}],
#   'member': '5072',
#   'container-title': ['Canadian Journal of Nursing Leadership'],
#   'deposited': {'date-parts': [[2017, 4, 25]],
#    'date-time': '2017-04-25T11:08:06Z',
#    'timestamp': 1493118486000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://www.longwoods.com/content/24987'}},
#   'issued': {'date-parts': [[2106, 12, 6]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '4',
#    'published-print': {'date-parts': [[2106, 12, 6]]}},
#   'URL': 'https://doi.org/10.12927/cjnl.2016.24987',
#   'ISSN': ['1929-6355'],
#   'issn-type': [{'value': '1929-6355', 'type': 'electronic'}],
#   'published': {'date-parts': [[2106, 12, 6]]}},
#  {'indexed': {'date-parts': [[2024, 7, 2]],
#    'date-time': '2024-07-02T21:18:27Z',
#    'timestamp': 1719955107690},
#   'reference-count': 0,
#   'publisher': 'Longwoods Publishing',
#   'issue': '4',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['CJNL'],
#   'published-print': {'date-parts': [[2106, 12, 6]]},
#   'DOI': '10.12927/cjnl.2016.24985',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2017, 4, 25]],
#    'date-time': '2017-04-25T11:08:02Z',
#    'timestamp': 1493118482000},
#   'page': '35-45',
#   'source': 'Crossref',
#   'is-referenced-by-count': 5,
#   'title': ['Implementing a Just Culture: Perceptions of Nurse Managers of Required Knowledge, Skills and Attitudes'],
#   'prefix': '10.12927',
#   'volume': '29',
#   'author': [{'given': 'Michelle',
#     'family': 'Freeman',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'Linda',
#     'family': 'Morrow',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'Margo',
#     'family': 'Cameron',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'Karen',
#     'family': 'McCullough',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '5072',
#   'container-title': ['Canadian Journal of Nursing Leadership'],
#   'deposited': {'date-parts': [[2017, 4, 25]],
#    'date-time': '2017-04-25T11:08:08Z',
#    'timestamp': 1493118488000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://www.longwoods.com/content/24985'}},
#   'issued': {'date-parts': [[2106, 12, 6]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '4',
#    'published-print': {'date-parts': [[2106, 12, 6]]}},
#   'URL': 'https://doi.org/10.12927/cjnl.2016.24985',
#   'ISSN': ['1929-6355'],
#   'issn-type': [{'value': '1929-6355', 'type': 'electronic'}],
#   'published': {'date-parts': [[2106, 12, 6]]}},
#  {'indexed': {'date-parts': [[2022, 4, 3]],
#    'date-time': '2022-04-03T02:27:30Z',
#    'timestamp': 1648952850943},
#   'reference-count': 0,
#   'publisher': 'Longwoods Publishing',
#   'issue': '4',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['CJNL'],
#   'published-print': {'date-parts': [[2106, 12, 6]]},
#   'DOI': '10.12927/cjnl.2016.24982',
#   'type': 'journal-issue',
#   'created': {'date-parts': [[2017, 4, 25]],
#    'date-time': '2017-04-25T11:08:03Z',
#    'timestamp': 1493118483000},
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'prefix': '10.12927',
#   'volume': '29',
#   'member': '5072',
#   'container-title': ['Canadian Journal of Nursing Leadership'],
#   'deposited': {'date-parts': [[2017, 4, 25]],
#    'date-time': '2017-04-25T11:08:03Z',
#    'timestamp': 1493118483000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://www.longwoods.com/publications/nursingleadership/24982'}},
#   'issued': {'date-parts': [[2106, 12, 6]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '4',
#    'published-print': {'date-parts': [[2106, 12, 6]]}},
#   'URL': 'https://doi.org/10.12927/cjnl.2016.24982',
#   'ISSN': ['1929-6355'],
#   'issn-type': [{'value': '1929-6355', 'type': 'electronic'}],
#   'published': {'date-parts': [[2106, 12, 6]]}},
#  {'indexed': {'date-parts': [[2024, 9, 13]],
#    'date-time': '2024-09-13T00:17:01Z',
#    'timestamp': 1726186621941},
#   'reference-count': 0,
#   'publisher': 'Longwoods Publishing',
#   'issue': '4',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['CJNL'],
#   'published-print': {'date-parts': [[2106, 12, 6]]},
#   'DOI': '10.12927/cjnl.2016.24984',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2017, 4, 25]],
#    'date-time': '2017-04-25T07:08:02Z',
#    'timestamp': 1493104082000},
#   'page': '46-58',
#   'source': 'Crossref',
#   'is-referenced-by-count': 3,
#   'title': ['Optimizing Registered Nurse Roles in the Delivery of Cancer Survivorship Care within Primary Care Settings'],
#   'prefix': '10.12927',
#   'volume': '29',
#   'author': [{'given': 'Lindsay',
#     'family': 'Yuille',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'Denise',
#     'family': 'Bryant-Lukosius',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'Ruta',
#     'family': 'Valaitis',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'Lisa',
#     'family': 'Dolovich',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '5072',
#   'container-title': ['Canadian Journal of Nursing Leadership'],
#   'deposited': {'date-parts': [[2017, 4, 25]],
#    'date-time': '2017-04-25T07:08:09Z',
#    'timestamp': 1493104089000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://www.longwoods.com/content/24984'}},
#   'issued': {'date-parts': [[2106, 12, 6]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '4',
#    'published-print': {'date-parts': [[2106, 12, 6]]}},
#   'URL': 'https://doi.org/10.12927/cjnl.2016.24984',
#   'ISSN': ['1929-6355'],
#   'issn-type': [{'value': '1929-6355', 'type': 'electronic'}],
#   'published': {'date-parts': [[2106, 12, 6]]}},
#  {'indexed': {'date-parts': [[2022, 4, 1]],
#    'date-time': '2022-04-01T14:33:35Z',
#    'timestamp': 1648823615332},
#   'reference-count': 0,
#   'publisher': 'Longwoods Publishing',
#   'issue': '4',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['CJNL'],
#   'published-print': {'date-parts': [[2106, 12, 6]]},
#   'DOI': '10.12927/cjnl.2016.24986',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2017, 4, 25]],
#    'date-time': '2017-04-25T11:08:02Z',
#    'timestamp': 1493118482000},
#   'page': '19-34',
#   'source': 'Crossref',
#   'is-referenced-by-count': 2,
#   'title': ['Engaging Nursing Voice and Presence During the Federal Election Campaign 2015'],
#   'prefix': '10.12927',
#   'volume': '29',
#   'author': [{'given': 'Nora',
#     'family': 'Whyte',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'Susan',
#     'family': 'Duncan',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '5072',
#   'container-title': ['Canadian Journal of Nursing Leadership'],
#   'deposited': {'date-parts': [[2017, 4, 25]],
#    'date-time': '2017-04-25T11:08:07Z',
#    'timestamp': 1493118487000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://www.longwoods.com/content/24986'}},
#   'issued': {'date-parts': [[2106, 12, 6]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '4',
#    'published-print': {'date-parts': [[2106, 12, 6]]}},
#   'URL': 'https://doi.org/10.12927/cjnl.2016.24986',
#   'ISSN': ['1929-6355'],
#   'issn-type': [{'value': '1929-6355', 'type': 'electronic'}],
#   'published': {'date-parts': [[2106, 12, 6]]}},
#  {'indexed': {'date-parts': [[2025, 5, 27]],
#    'date-time': '2025-05-27T15:11:13Z',
#    'timestamp': 1748358673836},
#   'reference-count': 0,
#   'publisher': 'Longwoods Publishing',
#   'issue': '4',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['CJNL'],
#   'published-print': {'date-parts': [[2106, 12, 6]]},
#   'DOI': '10.12927/cjnl.2016.24989',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2017, 4, 25]],
#    'date-time': '2017-04-25T07:08:02Z',
#    'timestamp': 1493104082000},
#   'page': '8-9',
#   'source': 'Crossref',
#   'is-referenced-by-count': 5,
#   'title': ['When More Is Not Always Better: Choosing Nursing Interventions Wisely'],
#   'prefix': '10.12927',
#   'volume': '29',
#   'author': [{'given': 'Barb',
#     'family': 'Shellian',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'Wendy',
#     'family': 'Levinson',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '5072',
#   'container-title': ['Canadian Journal of Nursing Leadership'],
#   'deposited': {'date-parts': [[2017, 4, 25]],
#    'date-time': '2017-04-25T07:08:04Z',
#    'timestamp': 1493104084000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://www.longwoods.com/content/24989'}},
#   'issued': {'date-parts': [[2106, 12, 6]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '4',
#    'published-print': {'date-parts': [[2106, 12, 6]]}},
#   'URL': 'https://doi.org/10.12927/cjnl.2016.24989',
#   'ISSN': ['1929-6355'],
#   'issn-type': [{'value': '1929-6355', 'type': 'electronic'}],
#   'published': {'date-parts': [[2106, 12, 6]]}},
#  {'indexed': {'date-parts': [[2024, 8, 6]],
#    'date-time': '2024-08-06T22:58:45Z',
#    'timestamp': 1722985125690},
#   'reference-count': 0,
#   'publisher': 'Valley International',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['ijetst'],
#   'DOI': '10.18535/ijetst/v3i08.10',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2016, 8, 9]],
#    'date-time': '2016-08-09T07:36:43Z',
#    'timestamp': 1470728203000},
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Contour Based Real Time Multiple Object Tracking'],
#   'prefix': '10.18535',
#   'author': [{'name': 'Dept. of ECE, Channabasaveshwara Institute of Technology Gubbi, Karnataka India',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'Mrs Malleshwari',
#     'family': 'MS',
#     'sequence': 'first',
#     'affiliation': []}],
#   'member': '7803',
#   'published-online': {'date-parts': [[2106, 8, 9]]},
#   'container-title': ['International journal of Emerging Trends in Science and Technology'],
#   'original-title': ['Contour Based Real Time Multiple Object Tracking'],
#   'deposited': {'date-parts': [[2016, 8, 9]],
#    'date-time': '2016-08-09T07:36:44Z',
#    'timestamp': 1470728204000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'http://ijetst.in/article/v3-i8/10%20ijetst.pdf'}},
#   'issued': {'date-parts': [[2106, 8, 9]]},
#   'references-count': 0,
#   'URL': 'https://doi.org/10.18535/ijetst/v3i08.10',
#   'ISSN': ['2348-9480'],
#   'issn-type': [{'type': 'electronic', 'value': '2348-9480'}],
#   'published': {'date-parts': [[2106, 8, 9]]}},
#  {'indexed': {'date-parts': [[2025, 6, 23]],
#    'date-time': '2025-06-23T05:45:24Z',
#    'timestamp': 1750657524218},
#   'reference-count': 0,
#   'publisher': 'Impact Journals, LLC',
#   'issue': '27',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['Oncotarget'],
#   'published-print': {'date-parts': [[2106, 7, 5]]},
#   'DOI': '10.18632/oncotarget.v7i27',
#   'type': 'journal-issue',
#   'created': {'date-parts': [[2020, 7, 15]],
#    'date-time': '2020-07-15T15:15:29Z',
#    'timestamp': 1594826129000},
#   'source': 'Crossref',
#   'is-referenced-by-count': 10,
#   'prefix': '10.18632',
#   'volume': '7',
#   'member': '7892',
#   'container-title': ['Oncotarget'],
#   'language': 'en',
#   'deposited': {'date-parts': [[2020, 7, 15]],
#    'date-time': '2020-07-15T15:15:29Z',
#    'timestamp': 1594826129000},
#   'score': 1.0,
#   'resource': {'primary': {'URL': 'https://www.oncotarget.com/lookup/doi/10.18632/oncotarget.v7i27'}},
#   'issued': {'date-parts': [[2106, 7, 5]]},
#   'references-count': 0,
#   'journal-issue': {'issue': '27',
#    'published-print': {'date-parts': [[2106, 7, 5]]}},
#   'URL': 'https://doi.org/10.18632/oncotarget.v7i27',
#   'ISSN': ['1949-2553'],
#   'issn-type': [{'value': '1949-2553', 'type': 'electronic'}],
#   'published': {'date-parts': [[2106, 7, 5]]}}]

# %% [markdown]
# #### src/transform_load.py

# %%
import os
import json
import pandas as pd
from sqlalchemy import create_engine, text
import pymysql
import sqlalchemy

# %%
#OPTIONAL DONT RUN IT! 
# Tell Python where to find src/ At the top of your notebook:
import os, sys

# adjust the path so Python can import from src/
sys.path.insert(0, os.path.abspath("src"))

# now you can import your ETL functions
from transform_load import load_raw_items, normalize, create_and_load

# %%
# OPTIONAL DONT RUN IT!
# Override RAW-DIR if needed
# after importing, re-point RAW_DIR for notebook context
from transform_load import RAW_DIR as _orig_raw_dir
import os
RAW_DIR = os.path.abspath("data/raw")

# %%
# OPTIONAL DONT RUN IT!
# Run your pipeline interactively
raw = load_raw_items(RAW_DIR)
dates, sources, authors, pubs, pub_auth = normalize(raw)
create_and_load(dates, sources, authors, pubs, pub_auth)

# %% [markdown]
# ######    ───── CONFIG  part   ───── ───── ───── ───── ───── ───── ───── ─────

# %%
# 1) Point this at your MySQL DW (replace placeholders):
DB_URI = "mysql+pymysql://Milosh_85:Nikoljdan2021@127.0.0.1:3306/scilit_db"

# %%
DB_URI
# Out:
# 'mysql+pymysql://Milosh_85:Nikoljdan2021@127.0.0.1:3306/scilit_db'

# %%
# validation script 
# DODATNO UREDJIVANJE VIDETI KAKO DA SE TOKENIZUJU KREDENCIJALI DA NE BUDU "OGOLJENI" U SKRIPTI 

from sqlalchemy import create_engine, text
from sqlalchemy.exc import SQLAlchemyError

def validate_mysql_connection(db_user, db_password, db_host, db_name):
    
    connection_string = f"mysql+pymysql://{db_user}:{db_password}@{db_host}/{db_name}"
    engine = create_engine(connection_string) #None  # Initialize engine outside try block

    try:
        with engine.connect() as conn:
            # Execute a simple query to verify connection
            version = conn.execute(text("SELECT DATABASE();")).scalar()
            print(f"Successfully connected to MySQL. Database version: {version}")
            return True
    except SQLAlchemyError as e:
        print(f"Error connecting to MySQL: {e}")
        return False
    finally:
        if engine:
            engine.dispose() # Dispose of the engine to close connections in the pool
            
if __name__ == "__main__":
# Replace with your actual database credentials
    USER = "Milosh_85"
    PASSWORD = "Nikoljdan2021"
    HOST = "127.0.0.1"
    DATABASE = "scilit_db"

validate_mysql_connection(USER, PASSWORD, HOST, DATABASE)
# Out:
# Successfully connected to MySQL. Database version: scilit_db
# True

# %%
validate_mysql_connection(USER, PASSWORD, HOST, DATABASE)
# Out:
# Successfully connected to MySQL. Database version: 8.0.29
# True

# %%
os.getcwd()
# Out:
# 'C:\\Users\\milos\\OneDrive\\Programming\\15. Python\\MDPI'

# %%
# 2) Raw JSON folder (created by ingest.py)
RAW_DIR = os.path.join(os.path.dirname(os.getcwd()), "MDPI\data\\raw")

# %%
RAW_DIR
# Out:
# 'C:\\Users\\milos\\OneDrive\\Programming\\15. Python\\MDPI\\data\\raw'

# %%
# Table names

TABLES = ["dates", "sources", "authors", "publications", "publication_authors"]

# %%
TABLES
# Out:
# ['dates', 'sources', 'authors', 'publications', 'publication_authors']

# %% [markdown]
# ######  ───── FUNCTIONS part ────────────────────────────────────────────────────────────

# %%
def load_raw_items(raw_dir):# imamo praznu listu, zatim kreiramo putanju gde nam je prvi deo apstrakcija/ direktorijum raw_dir 
    """Read every .json in data/raw/ into a list of dicts."""#  na koji nadovezujemo ime objekta unutar direktorijuma
    items = [] # zatim otvaramo context manager sa with open() dajemo mu apsktakciju f , citamo sadrzaj contexta file-like objecta 
    for fn in os.listdir(raw_dir):#koji zatim uvcitavamo u native python object , items tj lista
        if fn.endswith(".json"):
            path = os.path.join(raw_dir, fn)
            with open(path, "r", encoding="utf-8") as f:
                items.append(json.load(f))
    return items

# %% [markdown]
# 01/07/2025 krecem sa def_Normalize() funckijom

# %%
def normalize(items):
    """
    Turn raw items into five flat record lists:
      - dates, sources, authors, publications, and publication_authors
    """
    dates, sources, authors, pubs, pub_auth = [], [], [], [], []  #5 empty lists to store final rows for each table
    date_map, source_map, author_map = {}, {}, {} # 3 empty dictionaries for deduplication (so we don’t re-insert the same source, date, or author)

    for pub_idx, itm in enumerate(items, start=1):  # 🔁 Loop through every publication itm, and keep count (pub_idx) starting at 1 
        # ── Dates dim ─────────────────────             (this will be the publication’s ID). This is key for relational mapping.
        date_parts = itm.get("issued", {}).get("date-parts", [[None, None, None]])[0]
        y, m, d = (date_parts + [None, None, None])[:3]
        date_key = f"{y}-{m}-{d}"
        if date_key not in date_map:
            date_map[date_key] = len(date_map) + 1
            dates.append({
                "date_id": date_map[date_key],
                "year": y, "month": m, "day": d
            })
        date_id = date_map[date_key]

# ── Sources dim ────────────────────
    src = itm.get("container-title", [None])[0]
    if src and src not in source_map:
        source_map[src] = len(source_map) + 1
        sources.append({
            "source_id": source_map[src],
            "source_name": src
            })
    src_id = source_map.get(src)

# ── Publications fact ──────────────
    pubs.append({
        "publication_id": pub_idx,
        "doi": itm.get("DOI"),
        "title": itm.get("title", [""])[0],
        "publisher": itm.get("publisher"),
        "type": itm.get("type"),
        "source_id": src_id,
        "issued_date_id": date_id
    })
# ── Authors & Bridge ───────────────
    for seq, auth in enumerate(itm.get("author", []), start=1):
        name_key = (auth.get("given"), auth.get("family"))
        # 🔁 Loop through all authors for this publication. seq helps keep track of author order (useful for citations).
        if name_key not in author_map:  # creating author row 
            author_map[name_key] = len(author_map) + 1
            aff = auth.get("affiliation", [])
            authors.append({
                "author_id": author_map[name_key],
                "given_name": name_key[0],
                "family_name": name_key[1],
                "affiliation": aff[0]["name"] if aff else None
                }) 
        # 📌 If this author is new (based on their name), assign a new ID and record them. Grab affiliation if available.
        a_id = author_map[name_key]
        pub_auth.append({
            "publication_id": pub_idx,
            "author_id": a_id,
            "sequence": seq
            })
    return dates, sources, authors, pubs, pub_auth

# %%
DB_URI
# Out:
# 'mysql+pymysql://Milosh_85:Nikoljdan2021@127.0.0.1:3306/scilit_db'

# %%
engine = create_engine("mysql+pymysql://Milosh_85:Nikoljdan2021@127.0.0.1:3306/scilit_db")
    #engine = create_engine(DB_URI, echo=False)

def create_and_load(dates, sources, authors, pubs, pub_auth):
    """Drop & recreate tables, then bulk-insert via pandas.to_sql()."""
    
    # 1) Dropping part (DDl) - Drop in reverse-dependency order . Child tables 
    # with FKs go first so you don’t violate referential integrity when dropping
    drop_order = [
         "publication_authors",
         "publications",
         "authors",
         "sources",
         "dates"
        ]
    # 2) Create tables (DDL) (parent → child)
    ddl_statements = [
        """
        CREATE TABLE dates (
          date_id INT NOT NULL,
          year INT,
          month INT,
          day INT,
          PRIMARY KEY (date_id)
        )""",
        """
        CREATE TABLE sources (
          source_id INT NOT NULL,
          source_name VARCHAR(255),
          PRIMARY KEY (source_id)
        )""",
        """
        CREATE TABLE authors (
          author_id INT NOT NULL,
          given_name VARCHAR(100),
          family_name VARCHAR(100),
          affiliation VARCHAR(255),
          PRIMARY KEY (author_id)
        )""",
        """
        CREATE TABLE publications (
          publication_id INT NOT NULL,
          doi VARCHAR(255),
          title VARCHAR(255),
          publisher VARCHAR(255),
          type VARCHAR(50),
          source_id INT,
          issued_date_id INT,
          PRIMARY KEY (publication_id),
          FOREIGN KEY (source_id) REFERENCES sources(source_id),
          FOREIGN KEY (issued_date_id) REFERENCES dates(date_id)
        )""",
        """
        CREATE TABLE publication_authors (
          publication_id INT,
          author_id INT,
          sequence INT,
          PRIMARY KEY (publication_id, author_id),
          FOREIGN KEY (publication_id) REFERENCES publications(publication_id),
          FOREIGN KEY (author_id) REFERENCES authors(author_id)
        )"""
        ]

    with engine.begin() as conn:
        for tbl in drop_order:
            conn.execute(text(f"DROP TABLE IF EXISTS {tbl}"))
        for stmt in ddl_statements:
            conn.execute(text(stmt))
            
    
    # 3) Bulk insert (we call con=engine instead of conn, as pandas now recognizes the engine and internally calls DBAPI to do the insert)
        pd.DataFrame(dates).to_sql(name = "dates", con=engine, if_exists="append", index=False)
        pd.DataFrame(sources).to_sql(name = "sources", con=engine, if_exists="append", index=False)
        pd.DataFrame(authors).to_sql(name = "authors", con=engine, if_exists="append", index=False)
        pd.DataFrame(pubs).to_sql(name = "publications", con=engine, if_exists="append", index=False)
        pd.DataFrame(pub_auth).to_sql(name = "publication_authors", con=engine, if_exists="append", index=False)

print("All tables created and loaded successfully.")
# Out:
# All tables created and loaded successfully.

# %%
#option b with adding a raw DBAPI connection to pandas 

# hand pandas an object that actually has .cursor(). The simplest is engine.raw_connection(). 
# For example, move your inserts outside the with engine.begin() block :

engine = create_engine("mysql+pymysql://Milosh_85:Nikoljdan2021@127.0.0.1:3306/scilit_db")
    #engine = create_engine(DB_URI, echo=False)

def create_and_load(dates, sources, authors, pubs, pub_auth):
    """Drop & recreate tables, then bulk-insert via pandas.to_sql()."""
    
    # 1) Dropping part (DDl) - Drop in reverse-dependency order Child tables 
    # with FKs go first so you don’t violate referential integrity when dropping
    drop_order = [
         "publication_authors",
         "publications",
         "authors",
         "sources",
         "dates"
        ]
    # 2) Create tables (DDL) (parent → child)
    ddl_statements = [
        """
        CREATE TABLE dates (
          date_id INT NOT NULL,
          year INT,
          month INT,
          day INT,
          PRIMARY KEY (date_id)
        )""",
        """
        CREATE TABLE sources (
          source_id INT NOT NULL,
          source_name VARCHAR(255),
          PRIMARY KEY (source_id)
        )""",
        """
        CREATE TABLE authors (
          author_id INT NOT NULL,
          given_name VARCHAR(100),
          family_name VARCHAR(100),
          affiliation VARCHAR(255),
          PRIMARY KEY (author_id)
        )""",
        """
        CREATE TABLE publications (
          publication_id INT NOT NULL,
          doi VARCHAR(255),
          title VARCHAR(255),
          publisher VARCHAR(255),
          type VARCHAR(50),
          source_id INT,
          issued_date_id INT,
          PRIMARY KEY (publication_id),
          FOREIGN KEY (source_id) REFERENCES sources(source_id),
          FOREIGN KEY (issued_date_id) REFERENCES dates(date_id)
        )""",
        """
        CREATE TABLE publication_authors (
          publication_id INT,
          author_id INT,
          sequence INT,
          PRIMARY KEY (publication_id, author_id),
          FOREIGN KEY (publication_id) REFERENCES publications(publication_id),
          FOREIGN KEY (author_id) REFERENCES authors(author_id)
        )"""
        ]

    with engine.begin() as conn:
        for tbl in drop_order:
            conn.execute(text(f"DROP TABLE IF EXISTS {tbl}"))
        for stmt in ddl_statements:
            conn.execute(text(stmt))
            
#3  Bulk‐load via pandas, using a raw DBAPI connection (moving to-sql() part out of the with engine.begin() block)
raw = engine.raw_connection()
try:
    pd.DataFrame(dates).to_sql(
        name="dates",
        con=raw,
        if_exists="append",
        index=False
    )
    pd.DataFrame(sources).to_sql(name = "sources", con=raw, if_exists="append", index=False)
    pd.DataFrame(authors).to_sql(name = "authors", con=raw, if_exists="append", index=False)
    pd.DataFrame(pubs).to_sql(name = "publications", con=raw, if_exists="append", index=False)
    pd.DataFrame(pub_auth).to_sql(name = "publication_authors", con=raw, if_exists="append", index=False)
    raw.commit()
finally:
    raw.close()

print("All tables created and loaded successfully.")
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# C:\Users\milos\AppData\Local\Temp\ipykernel_18968\3148162308.py:78: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.DataFrame(dates).to_sql(
# Traceback (most recent call last):
#   File "C:\Users\milos\anaconda3\lib\site-packages\pandas\io\sql.py", line 2664, in execute
#   File "C:\Users\milos\anaconda3\lib\site-packages\pymysql\cursors.py", line 146, in execute
#     query = self.mogrify(query, args)
#   File "C:\Users\milos\anaconda3\lib\site-packages\pymysql\cursors.py", line 125, in mogrify
#     query = query % self._escape_args(args, conn)
# TypeError: not all arguments converted during string formatting
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\milos\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3369, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\milos\AppData\Local\Temp\ipykernel_18968\3148162308.py", line 78, in <cell line: 77>
#     pd.DataFrame(dates).to_sql(
#   File "C:\Users\milos\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 333, in wrapper
#     ]
#   File "C:\Users\milos\anaconda3\lib\site-packages\pandas\core\generic.py", line 3106, in to_sql
#     if self.ndim == 1:
#   File "C:\Users\milos\anaconda3\lib\site-packages\pandas\io\sql.py", line 844, in to_sql
#   File "C:\Users\milos\anaconda3\lib\site-packages\pandas\io\sql.py", line 2840, in to_sql
#   File "C:\Users\milos\anaconda3\lib\site-packages\pandas\io\sql.py", line 986, in create
#     break
#   File "C:\Users\milos\anaconda3\lib\site-packages\pandas\io\sql.py", line 972, in exists
#     chunksize: str | None,
#   File "C:\Users\milos\anaconda3\lib\site-packages\pandas\io\sql.py", line 2855, in has_table
#   File "C:\Users\milos\anaconda3\lib\site-packages\pandas\io\sql.py", line 2676, in execute
# pandas.errors.DatabaseError: Execution failed on sql '
#         SELECT
#             name
#         FROM
#             sqlite_master
#         WHERE
#             type IN ('table', 'view')
#             AND name=?;
#         ': not all arguments converted during string formatting
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\milos\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 1982, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "C:\Users\milos\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1118, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "C:\Users\milos\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1012, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "C:\Users\milos\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 865, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "C:\Users\milos\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 818, in format_exception_as_a_whole
#     frames.append(self.format_record(r))
#   File "C:\Users\milos\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 736, in format_record
#     result += ''.join(_format_traceback_lines(frame_info.lines, Colors, self.has_colors, lvals))
#   File "C:\Users\milos\anaconda3\lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "C:\Users\milos\anaconda3\lib\site-packages\stack_data\core.py", line 698, in lines
#     pieces = self.included_pieces
#   File "C:\Users\milos\anaconda3\lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "C:\Users\milos\anaconda3\lib\site-packages\stack_data\core.py", line 649, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "C:\Users\milos\anaconda3\lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "C:\Users\milos\anaconda3\lib\site-packages\stack_data\core.py", line 628, in executing_piece
#     return only(
#   File "C:\Users\milos\anaconda3\lib\site-packages\executing\executing.py", line 164, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %%
# option c:with using SQLAlchemy.Connection  

engine = create_engine("mysql+pymysql://Milosh_85:Nikoljdan2021@127.0.0.1:3306/scilit_db")
    #engine = create_engine(DB_URI, echo=False)

def create_and_load(dates, sources, authors, pubs, pub_auth):
    """Drop & recreate tables, then bulk-insert via pandas.to_sql()."""
    
    # 1) Dropping part (DDl) - Drop in reverse-dependency order Child tables 
    # with FKs go first so you don’t violate referential integrity when dropping
    drop_order = [
        "publication_authors",
        "publications",
        "authors",
        "sources",
        "dates"
    ]
    # 2) Create tables (DDL) (parent → child)
    ddl_statements = [
        """
        CREATE TABLE dates (
          date_id INT NOT NULL,
          year INT,
          month INT,
          day INT,
          PRIMARY KEY (date_id)
        )""",
        """
        CREATE TABLE sources (
          source_id INT NOT NULL,
          source_name VARCHAR(255),
          PRIMARY KEY (source_id)
        )""",
        """
        CREATE TABLE authors (
          author_id INT NOT NULL,
          given_name VARCHAR(100),
          family_name VARCHAR(100),
          affiliation VARCHAR(255),
          PRIMARY KEY (author_id)
        )""",
        """
        CREATE TABLE publications (
          publication_id INT NOT NULL,
          doi VARCHAR(255),
          title VARCHAR(255),
          publisher VARCHAR(255),
          type VARCHAR(50),
          source_id INT,
          issued_date_id INT,
          PRIMARY KEY (publication_id),
          FOREIGN KEY (source_id) REFERENCES sources(source_id),
          FOREIGN KEY (issued_date_id) REFERENCES dates(date_id)
        )""",
        """
        CREATE TABLE publication_authors (
          publication_id INT,
          author_id INT,
          sequence INT,
          PRIMARY KEY (publication_id, author_id),
          FOREIGN KEY (publication_id) REFERENCES publications(publication_id),
          FOREIGN KEY (author_id) REFERENCES authors(author_id)
        )"""
        ]

    with engine.begin() as sa_conn:
        for tbl in drop_order:
            sa_conn.execute(text(f"DROP TABLE IF EXISTS {tbl}"))
        for stmt in ddl_statements:
            sa_conn.execute(text(stmt))
            
    # 3) Bulk insert (we call con=engine instead of conn, as pandas nwo recognizes the engine and internally calls DBAPI to to the insert)
        pd.DataFrame(dates).to_sql(name = "dates", con=sa_conn, if_exists="append", index=False)
        pd.DataFrame(sources).to_sql(name = "sources", con=sa_conn, if_exists="append", index=False)
        pd.DataFrame(authors).to_sql(name = "authors", con=sa_conn, if_exists="append", index=False)
        pd.DataFrame(pubs).to_sql(name = "publications", con=sa_conn, if_exists="append", index=False)
        pd.DataFrame(pub_auth).to_sql(name = "publication_authors", con=sa_conn, if_exists="append", index=False)

print("All tables created and loaded successfully.")
# Out:
# All tables created and loaded successfully.

# %%
print(pd.__version__)
# Out:
# 2.3.0+4.g1dfc98e16a

# %%
# !pip install pandas==1.3.5
# Out:
# Requirement already satisfied: pandas==1.3.5 in c:\users\milos\anaconda3\lib\site-packages (1.3.5)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\milos\anaconda3\lib\site-packages (from pandas==1.3.5) (1.22.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\milos\anaconda3\lib\site-packages (from pandas==1.3.5) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\milos\anaconda3\lib\site-packages (from pandas==1.3.5) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\milos\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas==1.3.5) (1.16.0)

# %%
pip install --upgrade pandas
# Out:
# Requirement already satisfied: pandas in c:\users\milos\anaconda3\lib\site-packages (2.2.3)Note: you may need to restart the kernel to use updated packages.
# Collecting pandas
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\milos\\anaconda3\\Lib\\site-packages\\~andas.libs\\msvcp140-0f2ea95580b32bcfc81c235d5751ce78.dll'
# Consider using the `--user` option or check the permissions.
#   Downloading pandas-2.3.0-cp39-cp39-win_amd64.whl (11.1 MB)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\milos\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\milos\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\milos\anaconda3\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\milos\anaconda3\lib\site-packages (from pandas) (1.22.4)
# Requirement already satisfied: six>=1.5 in c:\users\milos\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.3
#     Uninstalling pandas-2.2.3:
#       Successfully uninstalled pandas-2.2.3

# %%
# due to the constant fails when it comes to SQL Alchemy connectivity, i downloaded lower version fo pandas
>> pip install pandas==1.3.5
Installing collected packages: pandas
  Attempting uninstall: pandas
    Found existing installation: pandas 2.0.2

# %%
# Run your pipeline interactively
raw = load_raw_items(RAW_DIR)
dates, sources, authors, pubs, pub_auth = normalize(raw)
create_and_load(dates, sources, authors, pubs, pub_auth)
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# C:\Users\milos\AppData\Local\Temp\ipykernel_18968\636086712.py:73: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.DataFrame(dates).to_sql(name = "dates", con=sa_conn, if_exists="append", index=False)
# Traceback (most recent call last):
#   File "C:\Users\milos\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3369, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\milos\AppData\Local\Temp\ipykernel_18968\3272227355.py", line 4, in <cell line: 4>
#     create_and_load(dates, sources, authors, pubs, pub_auth)
#   File "C:\Users\milos\AppData\Local\Temp\ipykernel_18968\636086712.py", line 73, in create_and_load
#     pd.DataFrame(dates).to_sql(name = "dates", con=sa_conn, if_exists="append", index=False)
#   File "C:\Users\milos\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 333, in wrapper
#     ]
#   File "C:\Users\milos\anaconda3\lib\site-packages\pandas\core\generic.py", line 3106, in to_sql
#     if self.ndim == 1:
#   File "C:\Users\milos\anaconda3\lib\site-packages\pandas\io\sql.py", line 844, in to_sql
#   File "C:\Users\milos\anaconda3\lib\site-packages\pandas\io\sql.py", line 2840, in to_sql
#   File "C:\Users\milos\anaconda3\lib\site-packages\pandas\io\sql.py", line 986, in create
#     break
#   File "C:\Users\milos\anaconda3\lib\site-packages\pandas\io\sql.py", line 972, in exists
#     chunksize: str | None,
#   File "C:\Users\milos\anaconda3\lib\site-packages\pandas\io\sql.py", line 2855, in has_table
#   File "C:\Users\milos\anaconda3\lib\site-packages\pandas\io\sql.py", line 2662, in execute
# AttributeError: 'Connection' object has no attribute 'cursor'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\milos\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 1982, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "C:\Users\milos\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1118, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "C:\Users\milos\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1012, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "C:\Users\milos\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 865, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "C:\Users\milos\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 818, in format_exception_as_a_whole
#     frames.append(self.format_record(r))
#   File "C:\Users\milos\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 736, in format_record
#     result += ''.join(_format_traceback_lines(frame_info.lines, Colors, self.has_colors, lvals))
#   File "C:\Users\milos\anaconda3\lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "C:\Users\milos\anaconda3\lib\site-packages\stack_data\core.py", line 698, in lines
#     pieces = self.included_pieces
#   File "C:\Users\milos\anaconda3\lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "C:\Users\milos\anaconda3\lib\site-packages\stack_data\core.py", line 649, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "C:\Users\milos\anaconda3\lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "C:\Users\milos\anaconda3\lib\site-packages\stack_data\core.py", line 628, in executing_piece
#     return only(
#   File "C:\Users\milos\anaconda3\lib\site-packages\executing\executing.py", line 164, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %% [markdown]
# ## Transform part
